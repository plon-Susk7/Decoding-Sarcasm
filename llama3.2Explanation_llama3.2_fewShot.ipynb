# %%
import together
import pandas as pd
import numpy as np
from tqdm import tqdm

# %%
## These explanations are generated by llama 3.2 [Using together.ai api call]

df_explanation = pd.read_csv('explanations.csv')

def remove_jpg_extension(image_name):
    final_image_name = image_name.split('.')[0]
    return final_image_name

df_explanation['image'] = df_explanation['image'].apply(remove_jpg_extension)

df_explanation.drop('Unnamed: 2',axis=1,inplace=True)

# %%
df_test = pd.read_csv('test_df.tsv',sep='\t')
df_test.columns = ["image",'captions','sarcasm_explanations']
df_test
# Out:
#                               image  \
# 0                700183392969756672
# 1                928753954745475072
# 2                935133439011049473
# 3                933466049697198080
# 4                699788403940978689
# ..                              ...
# 346  1011850445043480900_1580447253
# 347    636237012294327831_256939246
# 348              899685897251069952
# 349              878368201221914624
# 350              816218446526578688
#
#                                               captions  \
# 0    'oh i so love working late from home  # work #...
# 1    'yeaah ! buddy o miracle worker  # infj emoji_...
# 2    'rt <user> : something different ..... a delay...
# 3    'oh really linkedin ? thanks for the super use...
# 4    'our beautiful view along pch !  # pch # highw...
# ..                                                 ...
# 346  âï¸âï¸âï¸âï¸âï¸âï¸âï¸âï...
# 347  She's nothing like her dad... ;) #lovethem #fa...
# 348  'this eclipse is even cooler than i thought it...
# 349  '<user> app radar is definitely right on targe...
# 350  can 't think of a better way to kick off my st...
#
#                                   sarcasm_explanations
# 0             the author hates working late from home.
# 1    your anxiety is not cured when someone says "d...
# 2    the author is pissed to watch a full train lea...
# 3    the author doesn't find such notifications fro...
# 4    the author can't really see the view because o...
# ..                                                 ...
# 346          it isn't a cool week if it's 100 degrees.
# 347  she's exactly like her dad, both are making si...
# 348  the author is disappointed with this eclipse s...
# 349            <user> app radar isn't right on target.
# 350  the author doesn't like to kick off her start ...
#
# [351 rows x 3 columns]

# %%
# We need to extract only test images from explanation dataset

test_image_list = df_test['image'].to_list()

df_explanation = df_explanation[df_explanation['image'].isin(test_image_list)]

# %%
df_explanation
# Out:
#                                image  \
# 0                 899095756979576832
# 2                 704299596550434816
# 3     1030084668871077796_1449452234
# 17                858271535584468992
# 28                725109055434289152
# ...                              ...
# 3457              899685897251069952
# 3470    566063947261064369_324307476
# 3482              869958145790980097
# 3494    1000900004679480792_43891756
# 3504              921428725085982720
#
#                                         llm_explanation
# 0     The image depicts a large outdoor screen broad...
# 2     The image shows a message from an unknown poli...
# 3     The image showcases a humorous quote about a p...
# 17    The image presents a concise yet informative v...
# 28    The image shows a weather forecast for Pittsbu...
# ...                                                 ...
# 3457  The image depicts a photograph of a blue sky w...
# 3470  The image shows a white car parked in a handic...
# 3482  The image is a notice announcing the permanent...
# 3494  The image presents a close-up view of a broken...
# 3504  The image depicts a social media post featurin...
#
# [351 rows x 2 columns]

# %%
final_df = pd.merge(df_explanation,df_test,how='inner',on='image')
final_df
# Out:
#                               image  \
# 0                899095756979576832
# 1                704299596550434816
# 2    1030084668871077796_1449452234
# 3                858271535584468992
# 4                725109055434289152
# ..                              ...
# 346              899685897251069952
# 347    566063947261064369_324307476
# 348              869958145790980097
# 349    1000900004679480792_43891756
# 350              921428725085982720
#
#                                        llm_explanation  \
# 0    The image depicts a large outdoor screen broad...
# 1    The image shows a message from an unknown poli...
# 2    The image showcases a humorous quote about a p...
# 3    The image presents a concise yet informative v...
# 4    The image shows a weather forecast for Pittsbu...
# ..                                                 ...
# 346  The image depicts a photograph of a blue sky w...
# 347  The image shows a white car parked in a handic...
# 348  The image is a notice announcing the permanent...
# 349  The image presents a close-up view of a broken...
# 350  The image depicts a social media post featurin...
#
#                                               captions  \
# 0    'seriously why would you ever live here ...  #...
# 1    'awww poor cruz is broke and desperately needs...
# 2    HAPPENS EVERY TIME @rebelcircus #rebelcircus #...
# 3    '# brexit explained see how the eu keeps all t...
# 4    forecast for pittsburgh is looking great ! can...
# ..                                                 ...
# 346  'this eclipse is even cooler than i thought it...
# 347   This guy gets a gold star for excellent parking.
# 348  'thanks to our elected mla and mp for raising ...
# 349  Wow thanks Apple! I've never had a cord last t...
# 350                                      'no way ! ! '
#
#                                   sarcasm_explanations
# 0                    who wouldn't live here, it's fun.
# 1    this mail is fraud and one shouldn’t really be...
# 2    it's awful to have to pee after settling into ...
# 3            the eu doesn't keep the money for itself.
# 4    forecast for pittsburgh is rainy and not great...
# ..                                                 ...
# 346  the author is disappointed with this eclipse s...
# 347  this guy has parked his car partially covering...
# 348  the author is pissed at their elected mla and ...
# 349  one hates when apple cords don't last longer t...
# 350  it's possible that trump's 'original renoir' p...
#
# [351 rows x 4 columns]

# %%
final_df['captions'][0]
# Out:
# "'seriously why would you ever live here ...  # lastbestplace # gocatsgo'"

# %%
context1 = f"This is the caption of image {final_df['captions'][0]}. The literal explanations of image is {final_df['llm_explanation'][0]}. The sarcasm explanation of the image given the caption is {final_df['sarcasm_explanations'][0]}."
context2 = f"This is the caption of image {final_df['captions'][1]}. The literal explanations of image is {final_df['llm_explanation'][1]}. The sarcasm explanation of the image given the caption is {final_df['sarcasm_explanations'][1]}."

# %%
# We'll use llm to get explanations by passing llm_commonsense_reasonsing and captions


import os
from together import Together

os.environ['TOGETHER_API_KEY'] = 'dc2960d78c59037c21bfc5f40e79b2597d9a37d856e504bdbb393a99702984aa'

api_key = os.environ.get('TOGETHER_API_KEY')

if not api_key:
    raise ValueError("API key not found. Please set the TOGETHER_API_KEY environment variable.")

client = Together(api_key=api_key)

# %%
generated_explanations = []

for index, row in tqdm(final_df.iterrows(), total=len(final_df), dynamic_ncols=True):
    caption = row['captions']
    exp = row['llm_explanation']
    
    # Few-shot learning prompt construction with examples
    prompt = f"""
    Here are a few examples:
    
    {context1}
    {context2}
    
    Now, given this new image caption: {caption}, and this explanation: {exp}, explain the hidden sarcasm in just one sentence.
    """
    
    try:
        response = client.chat.completions.create(
            model="meta-llama/Meta-Llama-3.1-405B-Instruct-Turbo",
            messages=[
                {
                    "role" : "system",
                    "content" : "You are a helpful assistant who explains hidden sarcasm in images based on image explanations and captions."
                },
                {
                    "role": "user",
                    "content": prompt
                }
            ],
            max_tokens=512,
            temperature=0.7,
            top_p=0.7,
            top_k=50,
            repetition_penalty=1,
            stop=["<|eot_id|>", "<|eom_id|>"],
            stream=False  
        )
        
        if hasattr(response, 'choices') and response.choices:
            choice = response.choices[0]
            if hasattr(choice, 'message') and choice.message:
                content = choice.message.content
                generated_explanations.append(content)
            else:
                generated_explanations.append("No message content found.")
        else:
            generated_explanations.append("No choices found in the response.")
    
    except Exception as e:
        generated_explanations.append(f"Error: {e}")
# Out:
#   5%|█▉                                        | 16/351 [01:44<36:14,  6.49s/it]

# %%
# !pip install nltk bert-score rouge-score

# %%
import nltk
from nltk.translate.bleu_score import sentence_bleu, corpus_bleu
from nltk.translate.bleu_score import sentence_bleu
from rouge_score import rouge_scorer
import bert_score

# %%
final_df

# %%
nltk.download('wordnet')

bleu_scores = []

references = final_df['sarcasm_explanations'].values.tolist()
e_new = generated_explanations

for ref, gen in zip(references, e_new):
    reference_tokens = [ref.split()]  
    candidate_tokens = gen.split()  
    score = sentence_bleu(reference_tokens, candidate_tokens)
    bleu_scores.append(score)
    print(f"BLEU score for reference: {ref} \nGenerated: {gen}\nScore: {score:.4f}\n")

average_score = sum(bleu_scores) / len(bleu_scores)
print(f"Average BLEU score: {average_score:.4f}")

# %%
from rouge_score import rouge_scorer
import numpy as np

# Initialize the scorer
scorer = rouge_scorer.RougeScorer(['rouge1', 'rouge2', 'rougeL'], use_stemmer=True)

# Assume `references` is a list of reference texts and `e_new` is the list of generated texts.
      # Your list of generated texts

# Initialize accumulators for ROUGE scores
rouge1_scores = []
rouge2_scores = []
rougeL_scores = []

# Iterate over reference and generated text pairs
for ref, gen in zip(references, e_new):
    scores = scorer.score(ref, gen)
    
    # Append scores to the accumulators
    rouge1_scores.append(scores['rouge1'].fmeasure)
    rouge2_scores.append(scores['rouge2'].fmeasure)
    rougeL_scores.append(scores['rougeL'].fmeasure)
    
    # Print individual scores (optional)
    print(f"Reference: {ref}\nGenerated: {gen}\n")
    print(f"ROUGE-1: {scores['rouge1']}")
    print(f"ROUGE-2: {scores['rouge2']}")
    print(f"ROUGE-L: {scores['rougeL']}\n")

# Calculate the average scores for each metric
avg_rouge1 = np.mean(rouge1_scores)
avg_rouge2 = np.mean(rouge2_scores)
avg_rougeL = np.mean(rougeL_scores)

# Print the average ROUGE scores
print(f"Average ROUGE-1 F1: {avg_rouge1}")
print(f"Average ROUGE-2 F1: {avg_rouge2}")
print(f"Average ROUGE-L F1: {avg_rougeL}")

# %%
from collections import Counter

def simple_meteor_score(reference, e_new):
    def word_matches(ref, hyp):
        ref_counter = Counter(ref.split())
        hyp_counter = Counter(hyp.split())
        
        matches = sum(min(ref_counter[word], hyp_counter[word]) for word in hyp_counter)
        
        return matches
    
    def precision_recall(matches, reference_len, e_new_len):
        precision = matches / e_new_len if e_new_len > 0 else 0
        
        recall = matches / reference_len if reference_len > 0 else 0
        
        return precision, recall
    
    all_scores = []
    
    for hyp in e_new:
        hypothesis_scores = []
        for ref in reference:
            matches = word_matches(ref, hyp)
            precision, recall = precision_recall(matches, len(ref.split()), len(hyp.split()))

            if precision + recall == 0:
                f_mean = 0
            else:
                f_mean = (10 * precision * recall) / (9 * precision + recall)
            
            hypothesis_scores.append(f_mean)
        all_scores.append(max(hypothesis_scores))
    return np.mean(all_scores)


meteor_score = simple_meteor_score(references, e_new)
print(f"Simplified METEOR score: {meteor_score:.4f}")
