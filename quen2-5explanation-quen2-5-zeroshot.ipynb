# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# !pip install nltk bert-score rouge-score
# Out:
# Requirement already satisfied: nltk in /opt/conda/lib/python3.10/site-packages (3.2.4)
# Collecting bert-score
#   Downloading bert_score-0.3.13-py3-none-any.whl.metadata (15 kB)
# Collecting rouge-score
#   Downloading rouge_score-0.1.2.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from nltk) (1.16.0)
# Requirement already satisfied: torch>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from bert-score) (2.4.0+cpu)
# Requirement already satisfied: pandas>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from bert-score) (2.2.3)
# Requirement already satisfied: transformers>=3.0.0 in /opt/conda/lib/python3.10/site-packages (from bert-score) (4.45.1)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from bert-score) (1.26.4)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from bert-score) (2.32.3)
# Requirement already satisfied: tqdm>=4.31.1 in /opt/conda/lib/python3.10/site-packages (from bert-score) (4.66.4)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.10/site-packages (from bert-score) (3.7.5)
# Requirement already satisfied: packaging>=20.9 in /opt/conda/lib/python3.10/site-packages (from bert-score) (21.3)
# Requirement already satisfied: absl-py in /opt/conda/lib/python3.10/site-packages (from rouge-score) (1.4.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.9->bert-score) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.0.1->bert-score) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.0.1->bert-score) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.0.1->bert-score) (2024.1)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch>=1.0.0->bert-score) (3.15.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /opt/conda/lib/python3.10/site-packages (from torch>=1.0.0->bert-score) (4.12.2)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.0.0->bert-score) (1.12)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.0.0->bert-score) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.0.0->bert-score) (3.1.4)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch>=1.0.0->bert-score) (2024.6.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /opt/conda/lib/python3.10/site-packages (from transformers>=3.0.0->bert-score) (0.25.1)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.10/site-packages (from transformers>=3.0.0->bert-score) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.10/site-packages (from transformers>=3.0.0->bert-score) (2024.5.15)
# Requirement already satisfied: safetensors>=0.4.1 in /opt/conda/lib/python3.10/site-packages (from transformers>=3.0.0->bert-score) (0.4.5)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /opt/conda/lib/python3.10/site-packages (from transformers>=3.0.0->bert-score) (0.20.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->bert-score) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib->bert-score) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->bert-score) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->bert-score) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->bert-score) (10.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->bert-score) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->bert-score) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->bert-score) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->bert-score) (2024.8.30)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.0.0->bert-score) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.0.0->bert-score) (1.3.0)
# Downloading bert_score-0.3.13-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 kB 1.8 MB/s eta 0:00:00
# Building wheels for collected packages: rouge-score
#   Building wheel for rouge-score (setup.py) ... done
#   Created wheel for rouge-score: filename=rouge_score-0.1.2-py3-none-any.whl size=24934 sha256=037f7f7d0dbcd0aa8ce197bc2a0f47d366b54de7ced1ab8c99917401e82d082a
#   Stored in directory: /root/.cache/pip/wheels/5f/dd/89/461065a73be61a532ff8599a28e9beef17985c9e9c31e541b4
# Successfully built rouge-score
# Installing collected packages: rouge-score, bert-score
# Successfully installed bert-score-0.3.13 rouge-score-0.1.2

# %%
# !pip install together
# Out:
# Collecting together
#   Downloading together-1.3.3-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp<4.0.0,>=3.9.3 in /opt/conda/lib/python3.10/site-packages (from together) (3.9.5)
# Requirement already satisfied: click<9.0.0,>=8.1.7 in /opt/conda/lib/python3.10/site-packages (from together) (8.1.7)
# Requirement already satisfied: eval-type-backport<0.3.0,>=0.1.3 in /opt/conda/lib/python3.10/site-packages (from together) (0.2.0)
# Requirement already satisfied: filelock<4.0.0,>=3.13.1 in /opt/conda/lib/python3.10/site-packages (from together) (3.15.1)
# Requirement already satisfied: numpy>=1.23.5 in /opt/conda/lib/python3.10/site-packages (from together) (1.26.4)
# Requirement already satisfied: pillow<11.0.0,>=10.3.0 in /opt/conda/lib/python3.10/site-packages (from together) (10.3.0)
# Requirement already satisfied: pyarrow>=10.0.1 in /opt/conda/lib/python3.10/site-packages (from together) (17.0.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.6.3 in /opt/conda/lib/python3.10/site-packages (from together) (2.9.2)
# Requirement already satisfied: requests<3.0.0,>=2.31.0 in /opt/conda/lib/python3.10/site-packages (from together) (2.32.3)
# Collecting rich<14.0.0,>=13.8.1 (from together)
#   Downloading rich-13.9.2-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: tabulate<0.10.0,>=0.9.0 in /opt/conda/lib/python3.10/site-packages (from together) (0.9.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.2 in /opt/conda/lib/python3.10/site-packages (from together) (4.66.4)
# Requirement already satisfied: typer<0.13,>=0.9 in /opt/conda/lib/python3.10/site-packages (from together) (0.12.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.9.3->together) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.9.3->together) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.9.3->together) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.9.3->together) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.9.3->together) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.9.3->together) (4.0.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/conda/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.6.3->together) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /opt/conda/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.6.3->together) (2.23.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in /opt/conda/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.6.3->together) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests<3.0.0,>=2.31.0->together) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests<3.0.0,>=2.31.0->together) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests<3.0.0,>=2.31.0->together) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests<3.0.0,>=2.31.0->together) (2024.8.30)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/lib/python3.10/site-packages (from rich<14.0.0,>=13.8.1->together) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/lib/python3.10/site-packages (from rich<14.0.0,>=13.8.1->together) (2.18.0)
# Requirement already satisfied: shellingham>=1.3.0 in /opt/conda/lib/python3.10/site-packages (from typer<0.13,>=0.9->together) (1.5.4)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich<14.0.0,>=13.8.1->together) (0.1.2)
# Downloading together-1.3.3-py3-none-any.whl (68 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.1/68.1 kB 2.3 MB/s eta 0:00:00
# Downloading rich-13.9.2-py3-none-any.whl (242 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.1/242.1 kB 8.1 MB/s eta 0:00:00
# Installing collected packages: rich, together
#   Attempting uninstall: rich
#     Found existing installation: rich 13.7.1
#     Uninstalling rich-13.7.1:
#       Successfully uninstalled rich-13.7.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ibis-framework 7.1.0 requires pyarrow<15,>=2, but you have pyarrow 17.0.0 which is incompatible.
# Successfully installed rich-13.9.2 together-1.3.3

# %%
import torch
import warnings
import pandas as pd
import time
import re
from dotenv import load_dotenv
import os
from together import Together
from transformers import AutoModelForCausalLM, AutoTokenizer, GenerationConfig, pipeline
from datasets import load_dataset
from tqdm import tqdm
warnings.filterwarnings('ignore')

# %%
df_explanation = pd.read_csv('/kaggle/input/explanation-test/explanations (1).csv')

def remove_jpg_extension(image_name):
    final_image_name = image_name.split('.')[0]
    return final_image_name

df_explanation['image'] = df_explanation['image'].apply(remove_jpg_extension)

df_explanation.drop('Unnamed: 2',axis=1,inplace=True)

# %%
df_test = pd.read_csv('/kaggle/input/explanation-test/test_df.tsv',sep='\t')
df_test.columns = ["image",'captions','sarcasm_explanations']
df_test
# Out:
#                               image  \
# 0                700183392969756672
# 1                928753954745475072
# 2                935133439011049473
# 3                933466049697198080
# 4                699788403940978689
# ..                              ...
# 346  1011850445043480900_1580447253
# 347    636237012294327831_256939246
# 348              899685897251069952
# 349              878368201221914624
# 350              816218446526578688
#
#                                               captions  \
# 0    'oh i so love working late from home  # work #...
# 1    'yeaah ! buddy o miracle worker  # infj emoji_...
# 2    'rt <user> : something different ..... a delay...
# 3    'oh really linkedin ? thanks for the super use...
# 4    'our beautiful view along pch !  # pch # highw...
# ..                                                 ...
# 346  âï¸âï¸âï¸âï¸âï¸âï¸âï¸âï...
# 347  She's nothing like her dad... ;) #lovethem #fa...
# 348  'this eclipse is even cooler than i thought it...
# 349  '<user> app radar is definitely right on targe...
# 350  can 't think of a better way to kick off my st...
#
#                                   sarcasm_explanations
# 0             the author hates working late from home.
# 1    your anxiety is not cured when someone says "d...
# 2    the author is pissed to watch a full train lea...
# 3    the author doesn't find such notifications fro...
# 4    the author can't really see the view because o...
# ..                                                 ...
# 346          it isn't a cool week if it's 100 degrees.
# 347  she's exactly like her dad, both are making si...
# 348  the author is disappointed with this eclipse s...
# 349            <user> app radar isn't right on target.
# 350  the author doesn't like to kick off her start ...
#
# [351 rows x 3 columns]

# %%
test_image_list = df_test['image'].to_list()

df_explanation = df_explanation[df_explanation['image'].isin(test_image_list)]

# %%
df_explanation
# Out:
#                                image  \
# 0                 899095756979576832
# 2                 704299596550434816
# 3     1030084668871077796_1449452234
# 17                858271535584468992
# 28                725109055434289152
# ...                              ...
# 3457              899685897251069952
# 3470    566063947261064369_324307476
# 3482              869958145790980097
# 3494    1000900004679480792_43891756
# 3504              921428725085982720
#
#                                         llm_explanation
# 0     The image depicts a large outdoor screen broad...
# 2     The image shows a message from an unknown poli...
# 3     The image showcases a humorous quote about a p...
# 17    The image presents a concise yet informative v...
# 28    The image shows a weather forecast for Pittsbu...
# ...                                                 ...
# 3457  The image depicts a photograph of a blue sky w...
# 3470  The image shows a white car parked in a handic...
# 3482  The image is a notice announcing the permanent...
# 3494  The image presents a close-up view of a broken...
# 3504  The image depicts a social media post featurin...
#
# [351 rows x 2 columns]

# %%
final_df = pd.merge(df_explanation,df_test,how='inner',on='image')
final_df
# Out:
#                               image  \
# 0                899095756979576832
# 1                704299596550434816
# 2    1030084668871077796_1449452234
# 3                858271535584468992
# 4                725109055434289152
# ..                              ...
# 346              899685897251069952
# 347    566063947261064369_324307476
# 348              869958145790980097
# 349    1000900004679480792_43891756
# 350              921428725085982720
#
#                                        llm_explanation  \
# 0    The image depicts a large outdoor screen broad...
# 1    The image shows a message from an unknown poli...
# 2    The image showcases a humorous quote about a p...
# 3    The image presents a concise yet informative v...
# 4    The image shows a weather forecast for Pittsbu...
# ..                                                 ...
# 346  The image depicts a photograph of a blue sky w...
# 347  The image shows a white car parked in a handic...
# 348  The image is a notice announcing the permanent...
# 349  The image presents a close-up view of a broken...
# 350  The image depicts a social media post featurin...
#
#                                               captions  \
# 0    'seriously why would you ever live here ...  #...
# 1    'awww poor cruz is broke and desperately needs...
# 2    HAPPENS EVERY TIME @rebelcircus #rebelcircus #...
# 3    '# brexit explained see how the eu keeps all t...
# 4    forecast for pittsburgh is looking great ! can...
# ..                                                 ...
# 346  'this eclipse is even cooler than i thought it...
# 347   This guy gets a gold star for excellent parking.
# 348  'thanks to our elected mla and mp for raising ...
# 349  Wow thanks Apple! I've never had a cord last t...
# 350                                      'no way ! ! '
#
#                                   sarcasm_explanations
# 0                    who wouldn't live here, it's fun.
# 1    this mail is fraud and one shouldn’t really be...
# 2    it's awful to have to pee after settling into ...
# 3            the eu doesn't keep the money for itself.
# 4    forecast for pittsburgh is rainy and not great...
# ..                                                 ...
# 346  the author is disappointed with this eclipse s...
# 347  this guy has parked his car partially covering...
# 348  the author is pissed at their elected mla and ...
# 349  one hates when apple cords don't last longer t...
# 350  it's possible that trump's 'original renoir' p...
#
# [351 rows x 4 columns]

# %%
import os
from together import Together

os.environ['TOGETHER_API_KEY'] = 'dc2960d78c59037c21bfc5f40e79b2597d9a37d856e504bdbb393a99702984aa'

api_key = os.environ.get('TOGETHER_API_KEY')

if not api_key:
    raise ValueError("API key not found. Please set the TOGETHER_API_KEY environment variable.")

client = Together(api_key=api_key)

# %%
generated_explanations = []

for index, row in tqdm(final_df.iterrows(),total=len(final_df),dynamic_ncols=True):
    caption = row['captions']
    exp = row['llm_explanation']
    
    prompt = f"Explain this caption: {caption} and this explanation that I got after image processing: {exp}, in just one sentence"
    
    try:
        response = client.chat.completions.create(
            model="Qwen/Qwen2.5-72B-Instruct-Turbo",
            messages=[
                {
                    "role": "user",
                    "content": prompt
                }
            ],
            max_tokens=512,
            temperature=0.7,
            top_p=0.7,
            top_k=50,
            repetition_penalty=1,
            stop=["<|eot_id|>", "<|eom_id|>"],
            stream=False  
        )
        
        if hasattr(response, 'choices') and response.choices:
            choice = response.choices[0]
            if hasattr(choice, 'message') and choice.message:
                content = choice.message.content
                generated_explanations.append(content)
            else:
                generated_explanations.append("No message content found.")
        else:
            generated_explanations.append("No choices found in the response.")
    
    except Exception as e:
        generated_explanations.append(f"Error: {e}")
# Out:
# 100%|██████████| 351/351 [07:51<00:00,  1.34s/it]

# %%
import nltk
from nltk.translate.bleu_score import sentence_bleu, corpus_bleu
from nltk.translate.bleu_score import sentence_bleu
from rouge_score import rouge_scorer
import bert_score

# %%
final_df
# Out:
#                               image  \
# 0                899095756979576832
# 1                704299596550434816
# 2    1030084668871077796_1449452234
# 3                858271535584468992
# 4                725109055434289152
# ..                              ...
# 346              899685897251069952
# 347    566063947261064369_324307476
# 348              869958145790980097
# 349    1000900004679480792_43891756
# 350              921428725085982720
#
#                                        llm_explanation  \
# 0    The image depicts a large outdoor screen broad...
# 1    The image shows a message from an unknown poli...
# 2    The image showcases a humorous quote about a p...
# 3    The image presents a concise yet informative v...
# 4    The image shows a weather forecast for Pittsbu...
# ..                                                 ...
# 346  The image depicts a photograph of a blue sky w...
# 347  The image shows a white car parked in a handic...
# 348  The image is a notice announcing the permanent...
# 349  The image presents a close-up view of a broken...
# 350  The image depicts a social media post featurin...
#
#                                               captions  \
# 0    'seriously why would you ever live here ...  #...
# 1    'awww poor cruz is broke and desperately needs...
# 2    HAPPENS EVERY TIME @rebelcircus #rebelcircus #...
# 3    '# brexit explained see how the eu keeps all t...
# 4    forecast for pittsburgh is looking great ! can...
# ..                                                 ...
# 346  'this eclipse is even cooler than i thought it...
# 347   This guy gets a gold star for excellent parking.
# 348  'thanks to our elected mla and mp for raising ...
# 349  Wow thanks Apple! I've never had a cord last t...
# 350                                      'no way ! ! '
#
#                                   sarcasm_explanations
# 0                    who wouldn't live here, it's fun.
# 1    this mail is fraud and one shouldn’t really be...
# 2    it's awful to have to pee after settling into ...
# 3            the eu doesn't keep the money for itself.
# 4    forecast for pittsburgh is rainy and not great...
# ..                                                 ...
# 346  the author is disappointed with this eclipse s...
# 347  this guy has parked his car partially covering...
# 348  the author is pissed at their elected mla and ...
# 349  one hates when apple cords don't last longer t...
# 350  it's possible that trump's 'original renoir' p...
#
# [351 rows x 4 columns]

# %%
y_true = final_df['sarcasm_explanations'].values.tolist()
y_pred = generated_explanations

bleu_1 = 0
bleu_2 = 0
bleu_3 = 0
bleu_4 = 0
count = 0
weights_1 = (1./1.,)
weights_2 = (1./2. , 1./2.)
weights_3 = (1./3., 1./3., 1./3.)
weights_4 = (1./4., 1./4., 1./4., 1./4.)
met = 0

for reference, hypothesis in zip(y_true, y_pred):
    # met += nltk.translate.meteor_score.meteor_score([reference], hypothesis)
    reference = reference.split()
    hypothesis = hypothesis.split()
    bleu_1 += sentence_bleu([reference], hypothesis, weights_1) 
    bleu_2 += sentence_bleu([reference], hypothesis, weights_2)
    bleu_3 += sentence_bleu([reference], hypothesis, weights_3)
    bleu_4 += sentence_bleu([reference], hypothesis, weights_4)
    count += 1

bleu_1 = bleu_1/count
bleu_2 = bleu_2/count
bleu_3 = bleu_3/count
bleu_4 = bleu_4/count
# met = met/count
print("BLEU-1:", bleu_1)
print("BLEU-2:", bleu_2)
print("BLEU-3:", bleu_3)
print("BLEU-4:", bleu_4)
# Out:
# BLEU-1: 0.08875802707520532
# BLEU-2: 0.17512699156054934
# BLEU-3: 0.2751579916916397
# BLEU-4: 0.357626349607834

# %%
nltk.download('wordnet')

bleu_scores = []

references = final_df['sarcasm_explanations'].values.tolist()
e_new = generated_explanations

for ref, gen in zip(references, e_new):
    reference_tokens = [ref.split()]  
    candidate_tokens = gen.split()  
    score = sentence_bleu(reference_tokens, candidate_tokens)
    bleu_scores.append(score)
    print(f"BLEU score for reference: {ref} \nGenerated: {gen}\nScore: {score:.4f}\n")

average_score = sum(bleu_scores) / len(bleu_scores)
print(f"Average BLEU score: {average_score:.4f}")
# Out:
# [nltk_data] Downloading package wordnet to /usr/share/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# BLEU score for reference: who wouldn't live here, it's fun.
# Generated: The caption humorously questions why anyone would live in such a place, despite the image showing a fun and relaxed outdoor event with people enjoying a football game or movie on a large screen, set against a picturesque backdrop.
# Score: 0.4002
#
# BLEU score for reference: this mail is fraud and one shouldn’t really be worried about it.
# Generated: The caption humorously expresses sympathy for Cruz, who is portrayed as financially struggling and urgently needing donations, while the image shows a plea from a politician (likely Cruz) asking for $456,291 to counter Donald Trump's attacks and continue their campaign, with a donation link at the bottom.
# Score: 0.4542
#
# BLEU score for reference: it's awful to have to pee after settling into bed with blankets, laptop, headphones, a drink and everything else.
# Generated: The image features a humorous quote about someone settling into bed with all comforts only to realize they need to use the restroom, set against a black background with a bold white font and a watermark "@REBEL CIRCUS," capturing a relatable and sarcastic moment.
# Score: 0.0620
#
# BLEU score for reference: the eu doesn't keep the money for itself.
# Generated: The caption and the image explanation together suggest a critical view of the EU's economic distribution, implying that the EU retains wealth for itself, while the infographic visually demonstrates that despite being part of the EU, some of the UK's poorest regions are among the most economically disadvantaged in Northern Europe, potentially supporting the caption's claim about the EU's role in economic disparities.
# Score: 0.4671
#
# BLEU score for reference: forecast for pittsburgh is rainy and not great, the author isn't excited to be home.
# Generated: The caption expresses excitement about the favorable weather forecast for Pittsburgh, showing mostly cloudy skies with temperatures ranging from 44°F to 75°F over the next week, and the anticipation of returning home.
# Score: 0.2789
#
# BLEU score for reference: one can't cheer for sad news.
# Generated: The caption and image depict a humorous and relatable moment where a student, after seeing someone cheating off their math test, messages the cheater to inform them that they both failed, set against a simple, stark background with a "SHARE" button to spread the joke.
# Score: 0.0000
#
# BLEU score for reference: obviously one would be buying things one brought to the cash counter.
# Generated: The caption humorously captures a teenager's exaggerated internal monologue at the grocery store, where they jokingly consider buying out the entire stock, leading to a playful exchange with the cashier who teasingly asks if they plan to steal the items, all part of a relatable and sarcastic "Teenager Post."
# Score: 0.4974
#
# BLEU score for reference: the author isn't having a great day at work in this picture.
# Generated: The caption "#tbt when I was having a great day at work" refers to a nostalgic moment, and the image shows a man posing confidently in front of a yellow wall with certificates and awards, wearing a white t-shirt and a red and black watch, resting his chin on his hand and looking directly at the camera.
# Score: 0.0649
#
# BLEU score for reference: store doesn't look great, there are many empty boxes.
# Generated: The caption praises the appearance of a store in Dearborn, MI, while the image actually shows a cluttered and disorganized warehouse area with worn and haphazardly stacked cardboard boxes.
# Score: 0.5125
#
# BLEU score for reference: cats make annoying obstacles to otherwise easy tasks like stretching.
# Generated: The caption humorously suggests that cats, like the black one standing on the yoga mat near the man's foot, can unexpectedly become adorable hindrances to simple activities such as stretching.
# Score: 0.5623
#
# BLEU score for reference: why wouldn't anyone want to stay in san diego, it's beautiful.
# Generated: The caption humorously questions why anyone would want to stay in San Diego, despite the image showcasing its breathtaking city skyline at dusk, serene waterfront, and majestic mountains, which collectively exude a peaceful and inviting atmosphere.
# Score: 0.0710
#
# BLEU score for reference: the author doesn't like such impolite note from her kid.
# Generated: The caption humorously describes a parent's reaction to finding a chocolate-stained note left by their child after a night out with friends, while the image adds to the humor with a hand-drawn "Mine" and a frowning face on a chocolate-stained paper, suggesting a playful and lighthearted situation.
# Score: 0.4542
#
# BLEU score for reference: it seems gun control isn't working well after all in chicago, it only took two hours for the first murder of 2016.
# Generated: The meme, attributed to the "Conservative American Network," sarcastically highlights Chicago's high crime rate by claiming the city had its first murder of 2016 just two hours into the new year, and the caption criticizes gun control efforts, suggesting they are ineffective.
# Score: 0.1468
#
# BLEU score for reference: someone's insensitive comment to get over it doesn't help.
# Generated: The caption and the comic strip together convey a satirical take on how people often dismiss others' feelings with insensitive comments, suggesting that if only we could instantly delete our feelings as easily as a computer file, we could respond to such insensitivity with humor and celebration, as depicted in the final panel where the character dances after being told to "get over it."
# Score: 0.4653
#
# BLEU score for reference: the author is disappointed with <user> for providing the uncomfortable wheelchair for her daughter.
# Generated: The caption expresses gratitude for a supportive wheelchair that aids the user's daughter, who is shown in the image sitting in a black wheelchair with pink accents, wearing a green jacket and a red bow, while holding her shoe in a public area near a Costa Coffee Express machine and a 1Life disability organization sign.
# Score: 0.5973
#
# BLEU score for reference: the author is pissed to have so much snow gathered on the car.
# Generated: The caption humorously describes the effort of digging a snow-covered white sedan out of a snowy parking lot at night, with the hashtags and emojis likely adding a playful or frustrated tone to the situation.
# Score: 0.5411
#
# BLEU score for reference: the author got her <user> sample in the mail and it's a tiny sample.
# Generated: The caption expresses excitement about receiving a sample of Tic Tac Mixers Peach Lemonade, which is showcased in a close-up image of its vibrant, ombre-packaged design featuring peaches, lemons, and bubbles, with the brand and flavor names prominently displayed in both English and French.
# Score: 0.5806
#
# BLEU score for reference: the difficulty of being one person trying to house <num> personalities, caffine, tattoo's and baking, that's not cool.
# Generated: The image shows a person in a stylish red and white gingham apron standing in front of a white door, exuding a warm and inviting vibe, which contrasts with the caption's commentary on the complexity of managing multiple personalities.
# Score: 0.5659
#
# BLEU score for reference: the author seems to be tired of managing the food for the dogs.
# Generated: The caption humorously describes the owner's dedication to managing the feeding of two small dogs, where one has food allergies and the other might overeat, while the image shows the white dog eating from a bowl on a mat with the brown dog resting nearby.
# Score: 0.2438
#
# BLEU score for reference: there're a lot of monitors in the studio.
# Generated: The caption humorously suggests a potential shortage of monitors in a well-equipped newsroom, which is actually filled with multiple television screens displaying live news, modern decor, and essential broadcast equipment, indicating a fully functional and technologically advanced broadcast studio.
# Score: 0.1162
#
# BLEU score for reference: the author hates paying for chunks of ice in the name of a smoothie.
# Generated: The image shows a person in a car holding a cup of a yellow beverage, likely a smoothie, with small ice cubes or fruit, while the caption humorously expresses frustration about the high cost of what is essentially "chunks of ice."
# Score: 0.2556
#
# BLEU score for reference: the author didn't find <user> a source of real news.
# Generated: The caption humorously suggests that the National Enquirer, known for sensational and often unreliable stories, is a source of "real news," while the image shows a magazine rack with the Enquirer featuring sensational headlines about Hillary Clinton, the Trump family, and celebrity gossip, alongside other products in a store.
# Score: 0.0922
#
# BLEU score for reference: there's something creepy about this panel.
# Generated: The caption humorously contrasts the seemingly friendly and unthreatening appearance of Uncle Joey, who invites children to listen to a story, with the #yikes hashtag, suggesting there might be something unsettling or inappropriate about the situation despite the panel's innocent appearance.
# Score: 0.4700
#
# BLEU score for reference: it wasn't a top level service from <user>.
# Generated: The caption praises Sprint Care for their consistent high-quality service, while the image shows a Twitter conversation where a customer named Brad is interacting with both Sprint Care and Verizon Support, indicating a complex customer service situation.
# Score: 0.4822
#
# BLEU score for reference: this isn't make-up, it's photoshoped.
# Generated: The caption humorously highlights the girl's improving makeup skills, noting her coordinated mascara and nails, while the image processing explanation describes a collage showing the same young blonde girl in black-and-white and color, both featuring her plaid shirt and chain-link bracelet.
# Score: 0.0000
#
# BLEU score for reference: innocent people and not the swiss bank account holders and 2g scam accused have to rush towards the banks as modiji is hunting black money.
# Generated: The caption suggests that individuals with Swiss bank accounts and those accused in the 2G scam are urgently rushing to banks, possibly to withdraw or hide their funds, as Prime Minister Modi intensifies efforts to track down black money, while the image shows a large, anxious crowd waiting outside a bank, each holding documents.
# Score: 0.6389
#
# BLEU score for reference: you've not made it in life when this is the view from your hotel room.
# Generated: The caption humorously suggests that a view of a well-maintained parking lot and commercial buildings from a hotel room is a sign of success, while the image description details a scene that contrasts the luxurious expectations typically associated with such a claim.
# Score: 0.5874
#
# BLEU score for reference: the author is disappointed with <user> for the very special delivery of not arriving on <num> separate booked dates.
# Generated: The caption expresses frustration with DX Delivery for failing to deliver a package on multiple scheduled dates, and the intent to escalate the issue to the company that used their service, while the image shows a poorly written email from DX Delivery explaining the delivery issue and providing contact information for a customer service agent.
# Score: 0.5747
#
# BLEU score for reference: saying "don't be sad." doesn't cure people.
# Generated: The image humorously depicts a sarcastic "thank you" for curing someone's sadness, likely meant to be a playful jab at overly simplistic attempts to comfort someone, and is branded with the @REBEL_CIRCUS watermark.
# Score: 0.4172
#
# BLEU score for reference: culvers bacon deluxe, it cannot get more unhealthy than this
# Generated: The caption humorously contrasts the indulgent, high-calorie nature of the Culver's Bacon Deluxe meal, which includes a double-patty cheeseburger with bacon, fries, and a drink, with the idea of "healthy living," while the image processing description confirms the meal's contents and packaging details.
# Score: 0.0000
#
# BLEU score for reference: there's no disk required for netflix and the author is asked to insert a disk for it.
# Generated: The caption expresses the user's confusion about Netflix requiring a disc, likely due to the Xbox Live service being down, while the image shows an Xbox One screen failing to start Netflix and asking for a disc insertion or system restart, with Minecraft prominently displayed.
# Score: 0.5774
#
# BLEU score for reference: chicken nuggets covered in hot sauce aren't healthy.
# Generated: The caption humorously contrasts the generally unhealthy perception of chicken nuggets with the idea of health, while the image shows a plate with a neat arrangement of crispy, pepper-seasoned nuggets drenched in a vibrant red hot sauce.
# Score: 0.2341
#
# BLEU score for reference: this is disgusting and misogynistic.
# Generated: The caption "how peaceful & loving" starkly contrasts with the controversial and violent content of the image, which includes a graphic quote from a religious text and a nude figure, creating a jarring and provocative statement.
# Score: 0.4082
#
# BLEU score for reference: the author isn't shocked that a big dirty truck doesn't know how to park in yeg.
# Generated: The caption criticizes a large, dirty truck for poor parking in Edmonton (YEG), noting it extends beyond the marked space, while the image shows a white pickup truck with a dirty bumper partially obscuring the license plate, parked slightly over the yellow line in a lot.
# Score: 0.2217
#
# BLEU score for reference: the author hates it when his mom forgets to get the only thing he asked her to get when she went shopping.
# Generated: The meme shows a man clapping in an office while captioning his frustration with his mom forgetting to buy the one thing he asked for, humorously highlighting a common relatable situation.
# Score: 0.1670
#
# BLEU score for reference: the author is wearing the blue jersey to show his support to team india but there's a power cut.
# Generated: The caption expresses support for Team India in a cricket match against New Zealand in Bangalore, mentioning power cuts and the local electricity provider, while the image processing description indicates that the associated image is a blank black square, likely a placeholder.
# Score: 0.6148
#
# BLEU score for reference: When preparing a presentation do not use giant fonts for everything, it does not make what you write correct
# Generated: The image humorously warns against the overuse of large fonts in presentations, suggesting that making the font huge can make any statement seem important, even if it's not, with a playful and visually striking design.
# Score: 0.5411
#
# BLEU score for reference: less thinking doesn't mean more happiness.
# Generated: The image shows a man and a dog sitting on a bench, with the dog's thought bubbles filled with simple, relatable images, suggesting that the dog's happiness stems from its straightforward and contented thoughts, unlike humans who often overthink, as implied by the caption "This is why dogs are happier."
# Score: 0.0000
#
# BLEU score for reference: windows updates aren't something that one wants when packing up to go home.
# Generated: The caption humorously expresses gratitude to Microsoft for ensuring the user has something to look forward to (a lengthy update process) when they are ready to leave, matching the image of a Windows update screen showing the installation of update two out of ninety-one, with a message advising against turning off the computer.
# Score: 0.4878
#
# BLEU score for reference: the author isn't being enthusiastic in the train.
# Generated: The caption humorously contrasts the man's enthusiastic expression in the selfie with the mundane setting of being on a train, while the image processing description mistakenly identifies the setting as an airplane cabin, detailing his blue polo shirt, jacket, and pompadour hairstyle.
# Score: 0.2321
#
# BLEU score for reference: the author's kids' lives aren't hell, they are happy.
# Generated: The caption sarcastically contrasts the apparent unhappiness of the kids in the image with the sympathetic and supportive tweet from Gregthurell, highlighting the discrepancy between the perceived and actual situations.
# Score: 0.4273
#
# BLEU score for reference: completely free at the theatre this morning
# Generated: The caption "super busy at the theatre this morning" contrasts with the tranquil scene of a quiet movie theater captured from a car's parking perspective, featuring a prominent marquee and a serene landscape, suggesting a discrepancy between the expected and observed activity levels.
# Score: 0.0534
#
# BLEU score for reference: it's no way to honor someone by taking to the streets, setting cars on fire, & looting a local mcdonalds.
# Generated: The image depicts a person standing in the middle of a smoke-filled road at night, with their arms raised, in front of a McDonald's, creating a dramatic and intense scene that contrasts with the familiar fast-food backdrop, seemingly in response to the caption's provocative and violent rhetoric.
# Score: 0.1930
#
# BLEU score for reference: out of the entire route 95, the worst roads are in nj, even though people pay their share of taxes.
# Generated: The caption criticizes New Jersey residents for poor road conditions on I-95, blaming inadequate tax contributions, while the image visually highlights the 51% of substandard road conditions in Essex County in 2015.
# Score: 0.5946
#
# BLEU score for reference: red with white screen and silver lined botton is a bad color combination.
# Generated: The caption humorously refers to the iPhone 7's color scheme, suggesting it could have been entirely red or red with a black front, while the image shows a pinkish-red iPhone 7 with a white screen and silver buttons on a white background.
# Score: 0.0699
#
# BLEU score for reference: the baby is crying in this picture.
# Generated: The caption expresses joy and nostalgia for a family portrait featuring a man, woman, and a crying baby, dressed formally in front of a house, with the baby's face blurred.
# Score: 0.5623
#
# BLEU score for reference: it's ridiculous that hillary clinton is resisting all the good things like clean energy.
# Generated: The caption and image series satirically portray Hillary Clinton as the leader of the resistance, highlighting her stance on progressive issues like healthcare, workers' rights, and reform, while also reflecting the polarized political sentiments surrounding her, as indicated by hashtags like #stillneverhillary and #demexit.
# Score: 0.4617
#
# BLEU score for reference: the author hates <user>'s growing a mustache because now her husband thinks he can have one too.
# Generated: The caption expresses gratitude to someone for growing a mustache, which inspired the man's husband to do the same, while the image shows a man with a neatly trimmed beard lying on a couch, capturing the essence of the #summerofstache trend.
# Score: 0.2222
#
# BLEU score for reference: she's exactly like her dad, both are making similar faces.
# Generated: The caption humorously suggests that the woman on the right, who is standing in front and wearing a light-colored sweater, doesn't resemble her father, despite the family's close bond, as shown in the selfie of the three individuals with a tech-lit background.
# Score: 0.3928
#
# BLEU score for reference: It was pretty much expected that they'll announce the new call of duty at the e3 expo 2016
# Generated: The promotional poster for Call of Duty: Black Ops III, featuring a soldier amidst drones and smoke, vividly captures the intense and unexpected announcement of the game's presence at E3 Expo 2016, thrilling fans who were not anticipating this reveal.
# Score: 0.5623
#
# BLEU score for reference: it's inconvenient driving home through the mountains in the rain with a vomiting kid.
# Generated: The caption humorously contrasts the idyllic yet challenging journey of driving through scenic, foggy mountains in the rain with a sick child, while the image depicts a serene and misty road winding through a forest, capturing the essence of a peaceful but potentially stressful vacation drive.
# Score: 0.1084
#
# BLEU score for reference: a fall, cool weather favorite <user> doesn't taste like the middle of summer.
# Generated: The caption humorously contrasts the early arrival of fall flavors in the middle of summer, while the image shows a pumpkin spice coffee advertisement celebrating National Coffee Month with a customer favorite, suggesting that fall flavors are being marketed prematurely.
# Score: 0.1078
#
# BLEU score for reference: the author is pissed at <user> for such bad packaging.
# Generated: The caption sarcastically thanks a company for consistently poor service, while the image shows a carefully packed item in a box, suggesting a contrast between the sender's effort and the recipient's dissatisfaction.
# Score: 0.5000
#
# BLEU score for reference: <user> didn't come out much better after cooking.
# Generated: The caption humorously suggests that the user improved after cooking, while the image shows a well-cooked, small, round pizza with pepperoni and cheese on a purple plate, indicating the quality of the cooking.
# Score: 0.4962
#
# BLEU score for reference: the author is not impressed by the rewards scheme since it's gonna take her twice as long now for free rewards.
# Generated: The caption and the image together suggest a scenario where the person is expressing frustration with changes to the Starbucks Rewards program. Here's a breakdown:
#
# ### Caption:
# "So much for free rewards, gonna take me twice as long now. thanks <user>"
#
# - **"So much for free rewards"**: This indicates disappointment or frustration with the changes to the rewards program. The person expected to receive free rewards more easily, but the changes have made it more difficult.
# - **"gonna take me twice as long now"**: This suggests that the new requirements for earning rewards are significantly more demanding, making it take twice as long to earn the same rewards as before.
# - **"thanks <user>"**: This is likely sarcastic, implying that the changes are not appreciated and that the person is not thankful for them.
#
# ### Image:
# The image shows a person holding a Starbucks Rewards pamphlet, with a blue toy car and other objects on the floor in the background. The pamphlet details the new reward program, which includes:
#
# - **Starting April 1, for every $1 spent, members will earn 2 stars, which can be redeemed for rewards.**
# - **Members can earn:**
#   - **1 star per visit**
#   - **30 stars to reach Gold level**
#   - **12 stars for a free reward in Gold level**
#   - **2 stars per $1 spent**
#   - **300 stars to reach Gold level**
#   - **125 stars for a free reward in Gold level**
#   - **Green and Gold levels, with new Gold benefits, in just one sentence**
#
# ### Explanation:
# The person is likely frustrated because the new reward system requires more stars to achieve the same benefits. For example, reaching the Gold level now requires 300 stars instead of 30, and earning a free reward in the Gold level now requires 125 stars instead of 12. This makes it much harder and time-consuming to earn rewards, hence the sarcastic "thanks" in the caption.
#
# The blue toy car and other objects in the background might be a personal touch, possibly indicating that the person is at home or in a casual setting while reviewing the new reward program.
# Score: 0.0369
#
# BLEU score for reference: such useless response doesn't make asos the most helpful of people.
# Generated: The caption sarcastically comments on ASOS's customer service, which informs the user that the return process has become more complicated and will take longer, despite the implication that ASOS should be helpful.
# Score: 0.4204
#
# BLEU score for reference: with such chillin pre-game in the rink lounge it's obvious how n has survived this for <num> years.
# Generated: The caption describes a group relaxing in a well-appointed sports lounge with a TV, fireplace, and comfortable seating, while the image processing explanation details the room's features, including a black wall with a TV showing a soccer game, a fireplace, black leather furniture, high-top tables, a window view of a stadium, and a red wall with a silver shutter.
# Score: 0.5103
#
# BLEU score for reference: the author is pissed at <user> for such outdated website about power outages.
# Generated: The user is impressed by the modern and informative design of the Tata Power website, which clearly communicates potential power outages, despite the inconvenience, and humorously suggests it's a fitting gift for Buddha Purnima.
# Score: 0.5857
#
# BLEU score for reference: the author doesn't look excited that it's time for a run.
# Generated: The caption expresses the man's excitement about going for a run, which is reflected in the image showing him dressed and ready, holding his phone to take a selfie with his dog.
# Score: 0.2345
#
# BLEU score for reference: some women just don’t know how to have natural eyebrows
# Generated: The meme depicts a scornful blonde woman, humorously captioned to comment on the irony of someone claiming their eyebrows look natural, suggesting they are obviously styled or enhanced.
# Score: 0.5170
#
# BLEU score for reference: it isn't a loss to not have to deal with someone who is rude to you.
# Generated: The meme humorously depicts Gene Wilder as Willy Wonka sarcastically responding to someone who claims they'll never return, by playfully suggesting that dealing with their rude behavior is not something to be missed.
# Score: 0.2950
#
# BLEU score for reference: this is a spam tweet.
# Generated: The caption 'good news! found a new job!' contrasts sharply with the image of a promoted tweet offering potentially lucrative daily earnings, suggesting a discrepancy between the stated good news and the actual content of the job offer.
# Score: 0.4028
#
# BLEU score for reference: this is a phishing email, no indicator can help you buy stocks that go up 100% of the time.
# Generated: The image depicts a promotional page for a stock market indicator that claims to help users identify and buy only stocks that are guaranteed to increase in price, supported by visually appealing charts and a compelling narrative, suggesting the potential for significant financial gains.
# Score: 0.2466
#
# BLEU score for reference: there are a lot of montreal media members at claude julien news conference in new york hotel.
# Generated: The caption and image description together suggest that the photo captures Claude Julien, likely the coach of the Montreal Canadiens (nicknamed #habs), at a press conference in a New York hotel during the 2017 Stanley Cup Playoffs, with a few Montreal media members in attendance, emphasizing the event's significance and the anticipation surrounding the playoffs.
# Score: 0.2620
#
# BLEU score for reference: the size of the author's largemouth bass is very small.
# Generated: The image shows a person in a boat proudly holding a small fish, humorously claiming to be the greatest fisherman ever, while the serene surroundings and their unique attire add to the whimsical scene.
# Score: 0.4925
#
# BLEU score for reference: snow showers aren't what the author wanted today.
# Generated: The caption expresses satisfaction with the weather app showing a 10% chance of snow in Richmond, with a temperature of 0 degrees and a wind chill between 1 and 4 degrees, set against a grey background.
# Score: 0.4855
#
# BLEU score for reference: that's a crude speech.
# Generated: The meme humorously presents Zimbabwe President Robert Mugabe's anti-racism speech in a playful font, captioned as a "perfect speech."
# Score: 0.4790
#
# BLEU score for reference: the author doesn't like to use windows, it's inconvenient.
# Generated: The caption 'Windows is such a joy to use' is likely sarcastic, given the image showing a slow and potentially tedious Windows installation process with a progress bar at only 10%.
# Score: 0.5040
#
# BLEU score for reference: over priced hotel food, subway or dunking donuts, the author doesn't have many choices in brooklyn tonight.
# Generated: The caption humorously contrasts overpriced hotel food with more affordable options like Subway or Dunkin' Donuts, reflecting the diverse and budget-friendly dining choices in Brooklyn, while the image processing description confirms the setting as a typical Subway restaurant with a variety of menu options.
# Score: 0.2267
#
# BLEU score for reference: it can't be just $10 for a kawasaki motorcycle.
# Generated: The caption expresses amazement at a Facebook ad for a black Kawasaki motorcycle priced at $10 on the Wish app, which is featured with a 5-star rating and a call to action to shop now.
# Score: 0.2241
#
# BLEU score for reference: the author is sad to live in a state that doesn't have their priorities right.
# Generated: The caption "happy to live in a state that has their priorities right. :) #chicago" suggests that the person is pleased with the policies or values of the state they live in, specifically Chicago. The use of a smiley face and the hashtag #chicago indicates a positive sentiment and a connection to the city.
#
# The image processing explanation reveals a receipt that includes a purchase of a "200z sugar tax bottle" for $0.20, with a total purchase amount of $32.09, including a tax of $0.19. The receipt also lists other items, such as Sprite Zero NR for $1.89 and Pump #3 for $30.00.
#
# The context of the caption and the receipt can be interpreted as follows: The person is likely happy about the state's implementation of a sugar tax, which is often seen as a measure to promote healthier choices and reduce sugar consumption. The small price of the sugar tax bottle ($0.20) and the minimal tax ($0.19) on the total purchase suggest that the state is applying the tax in a way that is not overly burdensome but still sends a message about health priorities. This aligns with the person's positive sentiment about living in a state that values health and well-being.
# Score: 0.0289
#
# BLEU score for reference: starbucks using these non-white cups for spring doesn't mean they hate white and are un-american.
# Generated: The caption expresses a misguided and racially charged interpretation of Starbucks' spring cup design, which features a teal cup with the phrase "Clean Me Spring!" written in black, while the image processing description clarifies that the cup has a white lid and is placed on a car dashboard.
# Score: 0.5000
#
# BLEU score for reference: it's not inspiring that trump doesn't know what is uranium precisely.
# Generated: The caption "inspiring quote for the day" is typically used to introduce a motivational or thought-provoking statement. However, in this context, the term "inspiring" might be used ironically, given the content of the quote.
#
# The image you described features a photograph of Donald Trump, the 45th President of the United States, standing at a podium with an American flag in the background. The quote displayed on the left-hand side of the image is:
#
# "You know what uranium is, right? It's this thing called nuclear weapons, and other things, like lots of things are done with uranium, including some bad things."
#
# This quote is attributed to Donald J. Trump, followed by his title as the 45th President of the United States of America.
#
# The quote itself is not particularly inspiring in the conventional sense. Instead, it reflects a casual and somewhat simplistic explanation of uranium, highlighting its role in nuclear weapons and other applications, some of which can be harmful. The use of the term "inspiring" here might be a form of satire, suggesting that the quote is more notable for its unconventional or unexpected nature rather than its motivational value.
# Score: 0.1182
#
# BLEU score for reference: renewing rivalry in a one-on-one battle is unoriginal, people have seen this before.
# Generated: The caption sarcastically praises the originality of a common scenario, while the image shows a locked iPhone screen with a WWE SmackDown notification about Sami Zayn and Kevin Owens, set against a background of raindrops on a glass surface.
# Score: 0.4002
#
# BLEU score for reference: the author is disappointed because his shift just ended and there's 10CM of snow outside covering his car.
# Generated: The caption expresses gratitude and humor towards Mother Nature for a 10cm snowfall, which perfectly ends a night shift, while the image shows a snow-covered silver Honda Civic parked at an angle on a snowy street.
# Score: 0.4855
#
# BLEU score for reference: Due to extreme winter he is not pumped.
# Generated: The caption 'he is pumped! #beenagreatconference #xtremewinter' reflects the excitement of an attendee at a lively indoor event, where a crowd of about 50 young adults is gathered in a well-lit room with a high ceiling and balcony, showing enthusiasm and engagement, likely during a conference or concert.
# Score: 0.3799
#
# BLEU score for reference: that book cover does look weird.
# Generated: The caption humorously contradicts the image of a simple, heartfelt "thank you" card with brown gloves on a wooden surface, suggesting that the scene actually looks quite unusual.
# Score: 0.4347
#
# BLEU score for reference: the <user> gt-r and <user> getz crdi aren't virtually twins, gt-r is better.
# Generated: The caption humorously compares a red Nissan GT-R and a red Hyundai Getz, parked side by side, to two monstrous "twins," referencing their similar red color and the Godzilla theme.
# Score: 0.5081
#
# BLEU score for reference: if something has to be delivered in nova scotia, <user> doesn't know the fastest way to deliver it.
# Generated: The caption humorously suggests that <user> is more reliable than the postal service for fast deliveries in Nova Scotia, as evidenced by the image showing multiple packages with delayed or in-transit statuses across various Canadian cities.
# Score: 0.5373
#
# BLEU score for reference: nobody likes when such situation happens.
# Generated: The caption and image humorously highlight the irony of being so sarcastic that people mistake your comments for genuine stupidity.
# Score: 0.0000
#
# BLEU score for reference: the author doesn't like <user>'s new pricing structure for power ups, totally not worth saving up to buy in bulk now.
# Generated: The caption praises the new pricing for power-ups in the Word Radar app, encouraging bulk purchases, while the image shows a screenshot of the app with a blue header, a shopping cart, and a table listing power-ups and games for purchase.
# Score: 0.2459
#
# BLEU score for reference: smoke coming out of the factory doesn't make clouds, it pollutes the air.
# Generated: The caption humorously suggests that the cloud-like plume of smoke from the power plant's cooling tower is actually how clouds are formed, while also hinting at the impact of industrial activities on air quality.
# Score: 0.5857
#
# BLEU score for reference: the author thinks a heart attack at mcdonald's isn't a surprise given the fast food being served there.
# Generated: The caption humorously suggests someone had a heart attack at McDonald's, likely due to the unhealthy nature of fast food, while the image shows an ambulance parked near a building that might be a McDonald's, with red trim hinting at a possible fire station nearby.
# Score: 0.0605
#
# BLEU score for reference: from this pic one could conclude that things aren't going great on turkey-eu front, given the way their representatives are looking, negative energy all around.
# Generated: The caption suggests a positive outlook on Turkey-EU relations, reflecting the formal and seemingly cordial meeting depicted in the image, where three professionally dressed men are seated with the flags of Turkey, the EU, and likely the European Commission in the background.
# Score: 0.5170
#
# BLEU score for reference: school finals is everyone's least favourite time of the year.
# Generated: The image captures a student's study space with a stack of academic books titled "PSYCHOLOGY," "PRECALCULUS," and "THE DEVELOPING CHILD," alongside a labeled water bottle, symbolizing dedication and preparation for finals.
# Score: 0.4238
#
# BLEU score for reference: joking about children getting shot isn't welcoming.
# Generated: The caption humorously describes a blunt, no-nonsense, and sarcastically welcoming Yorkshire pub sign that threatens to shoot children after 9 PM, while also requiring supervision and banning them from the bar area, reflecting a harsh but likely true local attitude.
# Score: 0.3976
#
# BLEU score for reference: no that's not what we do in this country: shoot people down for their political views, it's fascist.
# Generated: The caption sarcastically criticizes the Twitter post's endorsement of violence against political opponents, highlighting the concerning normalization of such fascist tendencies in the country.
# Score: 0.5373
#
# BLEU score for reference: poor people won't stop being poor just by saying so.
# Generated: The image contains a book description in Japanese with a barcode, ISBN, and logos, while the caption sarcastically criticizes government assistance and suggests that poor people should simply stop being poor.
# Score: 0.3045
#
# BLEU score for reference: india is not becoming complete democracy by giving citizenship rights to living beings other than humans.
# Generated: The caption humorously suggests that India's democratic processes have become so inclusive that even animals are being granted citizenship rights, as depicted by a lion and zebra peacefully drinking from the same water source, with the lion possibly seeking the zebra's vote in a forest election.
# Score: 0.4566
#
# BLEU score for reference: this sunday morning paper is objectifying women, this is some ugly fashion.
# Generated: The caption humorously contrasts the article's focus on fashion trends that objectify women, like plunging necklines, with the ironic claim that the paper doesn't objectify women, while the #uglyfashion tag criticizes the trend.
# Score: 0.4962
#
# BLEU score for reference: the author isn't excited for the trip with school having to wear awful shirts.
# Generated: The caption expresses sarcastic enthusiasm about a school trip and having to wear unappealing shirts, while the image shows two young women in a selfie, one covering her mouth and the other with messy hair, both possibly reflecting their mood about the situation.
# Score: 0.1212
#
# BLEU score for reference: the world doesn't need more thinkers like this, thinking about alcohols.
# Generated: The caption and the image explanation you provided are part of a humorous meme that plays on the idea of combining two popular beverages, Dr. Pepper and Fireball whiskey, into a single, makeshift drinking device. Here's a breakdown:
#
# ### Caption:
# "The world needs more great thinkers like this #fireball #fireballwhiskey #drpepper #alcohol #drink #drinking #genius"
#
# - **"The world needs more great thinkers like this"**: This phrase is a playful way of praising the creativity or ingenuity of the person who came up with the idea of combining the two drinks. It suggests that the idea is so clever that it should be celebrated.
# - **Hashtags**: The hashtags are used to tag the specific drinks and the context of the meme. They help to categorize the post and make it more discoverable on social media platforms.
#
# ### Image Explanation:
# "This image features a humorous meme with a photo of two drinks, a bottle of Dr. Pepper soda and a bottle of Fireball whiskey, connected by a straw to make a makeshift drinking contraption. The caption reads, 'The greatest invention in the history of mankind: of mankind.'"
#
# - **"This image features a humorous meme"**: The meme is designed to be funny and light-hearted.
# - **"a photo of two drinks, a bottle of Dr. Pepper soda and a bottle of Fireball whiskey, connected by a straw"**: This describes the visual element of the meme, where the two bottles are connected by a straw, creating a unique and unconventional way to consume both beverages.
# - **"to make a makeshift drinking contraption"**: This emphasizes the DIY and creative aspect of the setup.
# - **"The greatest invention in the history of mankind: of mankind"**: This is a humorous exaggeration, suggesting that the combination of Dr. Pepper and Fireball is so brilliant that it represents a major milestone in human history. The repetition of "of mankind" is likely a typo or a playful emphasis.
#
# ### Summary:
# The meme is a lighthearted celebration of a creative and somewhat absurd idea: combining Dr. Pepper and Fireball whiskey using a straw. The caption and hashtags reinforce the idea that this is a brilliant and worthy invention, even though it's clearly meant to be taken with a grain of salt.
# Score: 0.0779
#
# BLEU score for reference: the author is pissed to watch a full train leave station with half of them still on platform.
# Generated: The caption humorously contrasts the mundane frustration of a train delay with the sophisticated, ironic tone of a still from "The Servant," a 1960s film, by referencing a classic Monty Python phrase.
# Score: 0.6580
#
# BLEU score for reference: one doesn't want netflix reminding one of what a lazy piece of shit one is.
# Generated: The image features a humorous, all-caps quote about laziness and Netflix, with a watermark from @rebelcircus, emphasizing the relatable and sarcastic nature of enjoying a lazy binge-watching session.
# Score: 0.2510
#
# BLEU score for reference: the author was lied to have to wait for just a few minutes and had to wait for <num> minutes, this isn't a good tactic for getting customers in a good mood for chatting about whatever question they have since the long wait annoys people.
# Generated: The caption humorously comments on how optimistic wait time estimates, displayed in a clear and structured format to customers in line, can keep them in a good mood despite the actual wait time being longer, effectively using positive messaging to enhance customer experience.
# Score: 0.0720
#
# BLEU score for reference: reviewing the protected status of national monuments designated by the past 3 presidents isn't a main priority in the country and will not better the country.
# Generated: The caption sarcastically comments on the prioritization of reviewing national monuments' protected status, suggesting it's a major focus in the country and questioning what else the president could be doing, while the image shows a CNN news alert about this review on a smartphone.
# Score: 0.0686
#
# BLEU score for reference: the author seems to be a big <user> fan given her playlist.
# Generated: The caption humorously indicates that despite not being a fan, the user is engaging with Ariana Grande's music on Apple Music, which features a list of her albums and singles from 2014 and 2016.
# Score: 0.5450
#
# BLEU score for reference: the author doesn't like to kick off her start to school with some notes of classical liberalism.
# Generated: The caption humorously suggests that diving into notes on classical liberalism is the perfect way to begin the school year, while the image shows a notebook with detailed handwritten notes, a pen, and a laptop on a white surface, indicating a focused study session.
# Score: 0.6077
#
# BLEU score for reference: the author's sad he paid for a vip area in the nosebleeds when his ticket is the orchestra near the stage.
# Generated: The caption humorously expresses satisfaction with accidentally getting a VIP experience in the least desirable seats when the actual ticket was for the orchestra near the stage, while the image shows a relaxed outdoor concert setting with people gathered in lawn chairs near a stage.
# Score: 0.0720
#
# BLEU score for reference: the <user> hasn't let himself go during the off-season, he's in a good shape.
# Generated: The caption humorously suggests that the man, likely a Denver Broncos player, has improved his physique significantly during the off-season, contrasting with the image showing him in a team jersey at a press conference or interview.
# Score: 0.1432
#
# BLEU score for reference: dialysis isn't fun.
# Generated: The caption humorously contrasts the serious nature of dialysis treatment with the notion of having fun, while the image shows a man in a hospital bed with medical equipment, suggesting a lighthearted approach to a challenging situation.
# Score: 0.4055
#
# BLEU score for reference: the author isn't glad to have had jimmy with a shovel, rattlesnakes aren't scared of shovel.
# Generated: The image shows a man, presumably Jimmy, standing in a grassy field with a shovel, ready to ward off any rattlesnakes, set against a serene backdrop of a mountain range and a clear sky, creating a sense of safety and tranquility despite the potential danger.
# Score: 0.1090
#
# BLEU score for reference: thing that the author hates about snowstorms: how the roads get cleared at the expense of the sidewalks.
# Generated: The caption humorously notes that while snowstorms are generally disruptive, one positive aspect is that roads are often cleared more quickly and thoroughly than sidewalks, while the image shows a typical snowy scene with a white, snow-covered surface and some darker patches, capturing the essence of a snowy day.
# Score: 0.5915
#
# BLEU score for reference: there's no one outside the author's front door.
# Generated: The caption humorously contrasts a claim of hundreds of people lining up outside the speaker's door with an image showing a quiet suburban street, suggesting the speaker's statement is exaggerated or false.
# Score: 0.2119
#
# BLEU score for reference: the author doesn't care that facebook was down.
# Generated: The anime boy, with his distinctive long dark hair and a content smile, seems amused or unfazed by the news that Facebook was down, as indicated by the caption "facebook was down? how upsetting."
# Score: 0.5450
#
# BLEU score for reference: the author is pissed at <user>'s bad internet service.
# Generated: The caption "use <user> & save money spent on internet, coz u don't get any to be charged for. #frustrated" suggests that the person is trying to save money by not using the internet, but this leads to frustration because they can't access online services or content. The image shows an error message on a mobile device indicating that there is no internet connection, which aligns with the caption's sentiment of being unable to use the internet and the resulting frustration.
# Score: 0.4387
#
# BLEU score for reference: branding is important and yet such a trivial design is chosen.
# Generated: The caption humorously emphasizes the importance of branding and design, while the image shows a website with strong visual branding through the prominent display of "Dank Mobile" in white text on a yellow background.
# Score: 0.5450
#
# BLEU score for reference: nobody should listen to him, he doesn't know anyone's sexuality.
# Generated: The caption suggests that the person in question falsely believes they have the right to know and share others' private information, such as their sexuality, which is reflected in Nolan's tweet criticizing someone for feeling entitled due to their own perceived status or attributes.
# Score: 0.4617
#
# BLEU score for reference: that's wrong the bible isn't better than shakespeare and adam wasn't a rebel.
# Generated: The caption humorously suggests that the Bible surpasses Shakespeare in literary value and characterizes Adam as a rebel, which is echoed in the image's scholarly text analyzing the story of Adam and Eve under the title "Rebel With A Cause."
# Score: 0.5233
#
# BLEU score for reference: doing laundry is mundane and boring.
# Generated: The caption sarcastically comments on the mundane task of doing laundry, while the image processing description details a well-maintained washing machine in a laundromat with a digital control panel and notices, set on a brown tile floor.
# Score: 0.5336
#
# BLEU score for reference: the author is sad that greitens cut the child services budget.
# ...
# Score: 0.5170
#
# BLEU score for reference: the author is pissed at <user> for such a terrible piece of chicken.
# Generated: The caption humorously praises the chicken, while the image shows a KFC take-out box with fried chicken and sauce on a newspaper.
# Score: 0.5491
#
# BLEU score for reference: <user> is offering such poor super slow speeds in mumbai.
# Generated: The caption humorously praises the fast 4G speeds in Mumbai, despite the actual Speedtest results showing relatively slow download (0.68 Mbps) and upload (1.00 Mbps) speeds, with a ping of 34 milliseconds.
# Score: 0.2345
#
# BLEU score for reference: the author wouldn't have fun reading through such a bulky stack of youth force evaluations and summing them all up.
# Generated: The caption humorously describes the task of reading through a large stack of Youth Force evaluations, while the image shows a low-angle view of the colorful papers on a table with a wooden leg and a red chair in the background.
# Score: 0.3040
#
# BLEU score for reference: the dceu superman smiles sometimes.
# Generated: The caption "the dceu superman never smiles" contrasts with the image, which shows Henry Cavill, who played Superman in the DCEU, smiling in various photos, including one in the Superman costume.
# Score: 0.2383
#
# BLEU score for reference: meat thermometer isn't used to operate on the motherboard.
# Generated: The image humorously contrasts the precision of technical work with a casual, everyday tool, suggesting that technology in education can bridge such gaps by making complex processes more accessible and understandable.
# Score: 0.4238
#
# BLEU score for reference: bad weather for the eclipse today here in kc.
# Generated: The caption describes perfect weather for viewing the 2017 eclipse in Kansas City, while the image processing explanation describes a rainy day on a highway with a median, roundabout, cloverleaf interchange, and cloudy sky, which contradicts the clear weather mentioned in the caption.
# Score: 0.2294
#
# BLEU score for reference: there's excessive price increases in generic drugs, there's something wrong and the market isn't taking care of it.
# Generated: The caption "#rxstickershock - - yeah, there is nothing wrong and the market is taking care of it!" is a sarcastic response to the significant price increases of essential generic drugs, as shown in the table, highlighting the public's frustration with the pharmaceutical industry's pricing practices.
# Score: 0.0896
#
# BLEU score for reference: this is a trivial earthquake detection kit, not the greatest invention ever.
# Generated: The caption 'greatest invention ever' humorously refers to a simple earthquake detection kit, which consists of googly eyes and a sign, designed to comically "see" and alert users to earthquakes when placed on a wall.
# Score: 0.1263
#
# BLEU score for reference: she doesn't look joyful.
# Generated: The caption humorously contrasts the child's serious expression with the playful notion of being a "big bundle of Joy," while the image shows a toddler in a pink shirt with light brown hair looking quite solemn.
# Score: 0.0000
#
# BLEU score for reference: the cartoons are showing the finger which isn't a way to greet people.
# Generated: The image humorously depicts Sesame Street characters giving the middle finger and sarcastically saying "Have a great day motherfuckers!" in bold white letters, blending mischief and playful defiance with a touch of vulgarity.
# Score: 0.5491
#
# BLEU score for reference: just one metro every 10min is very inconvenient for a normal working day.
# Generated: The caption expresses surprise at the frequency of metro trains during peak hours, while the image shows a crowded, bustling train station with a digital schedule and security cameras, set in a chilly, open-air environment.
# Score: 0.4889
#
# BLEU score for reference: babysitting can be tiring.
# Generated: The caption "Babysitting is just great #sarcastic" suggests that the babysitting experience, despite the seemingly idyllic and playful scene of a boy running around a backyard with a dog and various fun objects like a trampoline and playhouse, is actually quite challenging and exhausting for the babysitter, hence the sarcasm.
# Score: 0.3761
#
# BLEU score for reference: the author is sad to have to spend the holidays in a hospital instead of sun, beach & the sea.
# Generated: The caption humorously suggests that hospital stays can be seen as an alternative to beach vacations, especially when one has the "option" to relax and not worry, while the image shows a monochromatic scene of someone reclining in a chair, possibly in a hospital, watching TV.
# Score: 0.2568
#
# BLEU score for reference: such situation wouldn't be lovely.
# Generated: The caption "lovely!! #appleevent" sarcastically comments on a meme showing a man with a battered face, humorously suggesting that his injuries are so severe that the new iPhone Face-ID can't recognize him.
# Score: 0.0000
#
# BLEU score for reference: the signage doesn't address the problems of bright lights from nightriders.
# Generated: The caption and image description together indicate that a new sign has been installed in a park in North Vancouver, addressing issues of light pollution from night riders and promoting respect for privacy, noise levels, and cleanliness, with gratitude for trail users' cooperation.
# Score: 0.4644
#
# BLEU score for reference: weather is beautiful in scotland.
# Generated: The caption expresses frustration with the unpredictable Scottish weather, while the image processing description portrays a tranquil Scottish beach scene with a serene ocean and a clear sky.
# Score: 0.0000
#
# BLEU score for reference: being stranded in austin with a flat and a spare that doesn't fit feels pretty bad.
# Generated: The image shows a sleek black car with a spare tire in a parking lot near a building labeled "godeli," illustrating the irony of feeling good despite being stranded in Austin with a flat tire and a spare that doesn't fit.
# Score: 0.1379
#
# BLEU score for reference: the author is disappointed with <user> for not enabling him to watch the nhl.
# Generated: The caption humorously expresses indifference to the NHL Winter Classic being unavailable, while the image shows a DirectTV service interruption message on a TV screen, apologizing for technical difficulties in both English and Spanish.
# Score: 0.5857
#
# BLEU score for reference: every winter, the author is reminded of how inconvenient it is to have a corner lot.
# Generated: The caption expresses joy about the benefits of a corner lot in winter, while the image shows a person bundled up in a snow-covered hooded jacket, standing outside on a cold day, with a blue sky and leafless trees in the background.
# Score: 0.2321
#
# BLEU score for reference: the author doesn't need a rodeohusband just so her fashion sense counts.
# Generated: The caption humorously expresses a desire for a 'rodeohusband' to validate the user's fashion sense before others notice they're single, while the image shows a notification that the Instagram account "rodeowives" has started following the user, featuring a profile picture of a couple in western attire.
# Score: 0.2097
#
# BLEU score for reference: the author doesn't seem busy looking at the type of apps.
# Generated: The caption "look at how busy I am" humorously suggests that the multitude of apps and a notification on the iPhone screen indicate a busy and active digital life.
# Score: 0.6444
#
# BLEU score for reference: 4 micro-USB cables in the car & not 1 iPhone cable doesn't make sense considering the author doesn't have any micro-USB devices & does have an iPhone.
# Generated: The caption humorously points out the irony of having multiple micro-USB cables in the car but no iPhone cable, despite not owning any micro-USB devices and owning an iPhone, while the image processing description highlights the variety of connectors, suggesting the person is tech-savvy but also a bit disorganized.
# Score: 0.1032
#
# BLEU score for reference: need human rights.
# Generated: The caption "no more human rights! #ge2017 #childrenofmen" and the image depict a dystopian scene of heavy police presence and crowd control, where a diverse group of people is confined and appears fearful, evoking themes of loss of freedom and human rights, similar to the film "Children of Men."
# Score: 0.3780
#
# BLEU score for reference: these aren't positive feedback.
# Generated: The caption sarcastically highlights the overwhelming positive feedback, contrasting with the hashtag suggestions of poor marketing and the need to fire the agency, while the image shows a clean, simple Fox Carolina webpage with a menu bar, search bar, and a list of varied comments.
# Score: 0.3861
#
# BLEU score for reference: the author hates winter, her windshield is covered with ice.
# Generated: The caption expresses sarcastic gratitude and frustration towards a harsh Iowa winter, while the image shows a car's icy windshield with a small clear patch, captured at night.
# Score: 0.6148
#
# BLEU score for reference: this board isn't clever.
# Generated: The image shows a sign from the GILLIO LAW FIRM in Slidell celebrating Veterans Day with a message that ties the importance of veterans to the NFL and free speech, while using a provocative tone to criticize those perceived as complainers, and is tagged with hashtags reflecting political and social sentiments.
# Score: 0.0000
#
# BLEU score for reference: this makes the author's mind clearer for not voting for trump.
# Generated: The caption expresses dissatisfaction with Hillary Clinton and Bernie Sanders, showing support for Donald Trump, while the image depicts a chaotic and tense scene at a postponed Trump rally, suggesting the rally was disrupted by an incident that caused panic and distress.
# Score: 0.4671
#
# BLEU score for reference: the author isn't enjoying this event due to such authentication errors.
# Generated: The caption expresses excitement about an event, while the image processing explanation describes a screen from the Pokémon Trainer Club app showing an authentication error with an "OK" button.
# Score: 0.5125
#
# BLEU score for reference: leak hasn't been fixed.
# Generated: The caption "leak fixed!" is ironic, as the image actually depicts a chaotic garage floor with a puddle of blood and a wrench, suggesting a violent or traumatic event rather than a simple leak repair.
# Score: 0.4111
#
# BLEU score for reference: this guy isn't racist, given he wants to include children of every color in the american dream.
# Generated: The caption criticizes Donald Trump as racist, using emojis for emphasis, despite the image showing him quoting a statement about addressing African-American poverty and inclusion in the American Dream.
# Score: 0.2465
#
# BLEU score for reference: bossiness isn't same as leadership and it shouldn't be the way forward.
# Generated: The caption humorously contrasts the playful, bossy interaction between two children in old-fashioned attire with a modern, empowering message about women in business, using lighthearted emojis and a supportive hashtag.
# Score: 0.5081
#
# BLEU score for reference: <user> is inconvenient for tall people due to so little leg room.
# Generated: The caption humorously suggests that the person is "super awesome for tall people" because the image shows a tall individual struggling with limited legroom in an airplane seat, a common issue for taller passengers, while the hashtag "#howisthislegal" questions the fairness of such cramped conditions.
# Score: 0.1973
#
# BLEU score for reference: <user>'s dagwood sandwich is too big to be eaten conveniently.
# Generated: The caption humorously suggests that the large sandwich, which is already bigger than the hand shown with a wedding band and fingers raised, should be even more enormous, emphasizing the idea with the hashtag "yuge."
# Score: 0.4889
#
# BLEU score for reference: the author is sad that if her kids get sick some druggo in bendigo is getting looked after better than them.
# Generated: The caption expresses frustration and irony, suggesting that the author feels their children would receive inferior medical care compared to drug users in Bendigo, where an article in the depicted newspaper discusses the rise in methamphetamine use and related health issues, including the spread of Hepatitis and AIDS through syringe use.
# Score: 0.1990
#
# BLEU score for reference: the author isn't good at drawing, look at this drawing.
# Generated: The caption "i can draw so good ..." humorously contrasts with the image, which shows a vibrant, well-detailed cartoon landscape of a sunset over blue water with palm trees, suggesting the artist's modesty or playful self-deprecation.
# Score: 0.4855
#
# BLEU score for reference: the author doesn't seem to love being out with their family.
# Generated: The caption expresses enthusiasm for family outings with a playful hint about pizza, while the image shows two fashionably dressed young people enjoying a meal in a lively, crowded restaurant.
# Score: 0.5081
#
# BLEU score for reference: it didn't go well, sniper was horrible.
# Generated: The caption humorously describes a successful but chaotic live streaming session, possibly featuring a sniper game, while the image shows a dark room setup with a microphone and a computer screen displaying a cartoon character and promotional text, suggesting it's a live stream or recording environment.
# Score: 0.3840
#
# BLEU score for reference: that's not the author's last name, it's a misprint.
# Generated: The caption humorously announces a name change, sarcastically suggesting it's a significant and sudden change, while the image shows an official envelope with a name scribbled out, likely mocking the idea of such a formal announcement for a trivial matter.
# Score: 0.2094
#
# BLEU score for reference: the author is disappointed with this eclipse since it's not what she thought it would be.
# Generated: The caption expresses excitement about the solar eclipse, despite a hint of disappointment, while the image description details a sky with a striking cloud formation that seems to be illuminated and moving away from the foreground.
# Score: 0.4855
#
# BLEU score for reference: this guy has parked his car partially covering the parking slot for handicapped.
# Generated: The caption sarcastically awards a "gold star" for poor parking, as the image shows a white car improperly occupying a handicap space at a Walmart, with no visible placard, and the car is parked in a way that blocks wheelchair access.
# Score: 0.5589
#
# BLEU score for reference: the author is pissed at their elected mla and mp for raising hell regards to their nw region losing a service for the people.
# Generated: The caption expresses gratitude to the local Member of the Legislative Assembly (MLA) and Member of Parliament (MP) for their efforts in protesting the closure of a service in the northwest region, which affects the local community. The image notice confirms the permanent closure of the Can/Sask Labour Market Services office in Ile a la Crosse, effective June 14, 2017, at 5 pm.
# Score: 0.2191
#
# BLEU score for reference: one hates when apple cords don't last longer than even 5 months.
# Generated: The caption sarcastically thanks Apple for a Lightning cable that has only lasted five months, shown in an image of a broken cord with a damaged white part and a silver connector, placed in front of a car's steering wheel.
# Score: 0.0000
#
# BLEU score for reference: it's possible that trump's 'original renoir' painting is fake.
# Generated: The caption "no way!!" expresses surprise or disbelief at the news that a painting claimed by Trump to be an original Renoir and owned by him is actually a fake, as declared by the Chicago museum, with the post garnering 677 likes and featuring a blurry image of the artwork.
# Score: 0.4949
#
# Average BLEU score: 0.3576

# %%
from rouge_score import rouge_scorer
import numpy as np

# Initialize the scorer
scorer = rouge_scorer.RougeScorer(['rouge1', 'rouge2', 'rougeL'], use_stemmer=True)

# Assume `references` is a list of reference texts and `e_new` is the list of generated texts.
      # Your list of generated texts

# Initialize accumulators for ROUGE scores
rouge1_scores = []
rouge2_scores = []
rougeL_scores = []

# Iterate over reference and generated text pairs
for ref, gen in zip(references, e_new):
    scores = scorer.score(ref, gen)
    
    # Append scores to the accumulators
    rouge1_scores.append(scores['rouge1'].fmeasure)
    rouge2_scores.append(scores['rouge2'].fmeasure)
    rougeL_scores.append(scores['rougeL'].fmeasure)
    
    # Print individual scores (optional)
    print(f"Reference: {ref}\nGenerated: {gen}\n")
    print(f"ROUGE-1: {scores['rouge1']}")
    print(f"ROUGE-2: {scores['rouge2']}")
    print(f"ROUGE-L: {scores['rougeL']}\n")

# Calculate the average scores for each metric
avg_rouge1 = np.mean(rouge1_scores)
avg_rouge2 = np.mean(rouge2_scores)
avg_rougeL = np.mean(rougeL_scores)

# Print the average ROUGE scores
print(f"Average ROUGE-1 F1: {avg_rouge1}")
print(f"Average ROUGE-2 F1: {avg_rouge2}")
print(f"Average ROUGE-L F1: {avg_rougeL}")
# Out:
# Reference: who wouldn't live here, it's fun.
# Generated: The caption humorously questions why anyone would live in such a place, despite the image showing a fun and relaxed outdoor event with people enjoying a football game or movie on a large screen, set against a picturesque backdrop.
#
# ROUGE-1: Score(precision=0.05128205128205128, recall=0.25, fmeasure=0.0851063829787234)
# ROUGE-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-L: Score(precision=0.05128205128205128, recall=0.25, fmeasure=0.0851063829787234)
#
# Reference: this mail is fraud and one shouldn’t really be worried about it.
# Generated: The caption humorously expresses sympathy for Cruz, who is portrayed as financially struggling and urgently needing donations, while the image shows a plea from a politician (likely Cruz) asking for $456,291 to counter Donald Trump's attacks and continue their campaign, with a donation link at the bottom.
#
# ROUGE-1: Score(precision=0.04081632653061224, recall=0.15384615384615385, fmeasure=0.06451612903225806)
# ROUGE-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-L: Score(precision=0.04081632653061224, recall=0.15384615384615385, fmeasure=0.06451612903225806)
#
# Reference: it's awful to have to pee after settling into bed with blankets, laptop, headphones, a drink and everything else.
# Generated: The image features a humorous quote about someone settling into bed with all comforts only to realize they need to use the restroom, set against a black background with a bold white font and a watermark "@REBEL CIRCUS," capturing a relatable and sarcastic moment.
#
# ROUGE-1: Score(precision=0.18181818181818182, recall=0.4, fmeasure=0.25000000000000006)
# ROUGE-2: Score(precision=0.06976744186046512, recall=0.15789473684210525, fmeasure=0.09677419354838708)
# ROUGE-L: Score(precision=0.13636363636363635, recall=0.3, fmeasure=0.18749999999999997)
#
# Reference: the eu doesn't keep the money for itself.
# Generated: The caption and the image explanation together suggest a critical view of the EU's economic distribution, implying that the EU retains wealth for itself, while the infographic visually demonstrates that despite being part of the EU, some of the UK's poorest regions are among the most economically disadvantaged in Northern Europe, potentially supporting the caption's claim about the EU's role in economic disparities.
#
# ROUGE-1: Score(precision=0.07462686567164178, recall=0.5555555555555556, fmeasure=0.13157894736842105)
# ROUGE-2: Score(precision=0.030303030303030304, recall=0.25, fmeasure=0.054054054054054064)
# ROUGE-L: Score(precision=0.07462686567164178, recall=0.5555555555555556, fmeasure=0.13157894736842105)
#
# Reference: forecast for pittsburgh is rainy and not great, the author isn't excited to be home.
# Generated: The caption expresses excitement about the favorable weather forecast for Pittsburgh, showing mostly cloudy skies with temperatures ranging from 44°F to 75°F over the next week, and the anticipation of returning home.
#
# ROUGE-1: Score(precision=0.23529411764705882, recall=0.5, fmeasure=0.31999999999999995)
# ROUGE-2: Score(precision=0.06060606060606061, recall=0.13333333333333333, fmeasure=0.08333333333333333)
# ROUGE-L: Score(precision=0.17647058823529413, recall=0.375, fmeasure=0.24)
#
# Reference: one can't cheer for sad news.
# Generated: The caption and image depict a humorous and relatable moment where a student, after seeing someone cheating off their math test, messages the cheater to inform them that they both failed, set against a simple, stark background with a "SHARE" button to spread the joke.
#
# ROUGE-1: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-L: Score(precision=0.0, recall=0.0, fmeasure=0.0)
#
# Reference: obviously one would be buying things one brought to the cash counter.
# Generated: The caption humorously captures a teenager's exaggerated internal monologue at the grocery store, where they jokingly consider buying out the entire stock, leading to a playful exchange with the cashier who teasingly asks if they plan to steal the items, all part of a relatable and sarcastic "Teenager Post."
#
# ROUGE-1: Score(precision=0.06, recall=0.25, fmeasure=0.0967741935483871)
# ROUGE-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-L: Score(precision=0.06, recall=0.25, fmeasure=0.0967741935483871)
#
# Reference: the author isn't having a great day at work in this picture.
# Generated: The caption "#tbt when I was having a great day at work" refers to a nostalgic moment, and the image shows a man posing confidently in front of a yellow wall with certificates and awards, wearing a white t-shirt and a red and black watch, resting his chin on his hand and looking directly at the camera.
#
# ROUGE-1: Score(precision=0.15517241379310345, recall=0.6923076923076923, fmeasure=0.2535211267605634)
# ROUGE-2: Score(precision=0.08771929824561403, recall=0.4166666666666667, fmeasure=0.14492753623188404)
# ROUGE-L: Score(precision=0.13793103448275862, recall=0.6153846153846154, fmeasure=0.22535211267605634)
#
# Reference: store doesn't look great, there are many empty boxes.
# Generated: The caption praises the appearance of a store in Dearborn, MI, while the image actually shows a cluttered and disorganized warehouse area with worn and haphazardly stacked cardboard boxes.
#
# ROUGE-1: Score(precision=0.06896551724137931, recall=0.2, fmeasure=0.10256410256410257)
# ROUGE-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-L: Score(precision=0.06896551724137931, recall=0.2, fmeasure=0.10256410256410257)
#
# Reference: cats make annoying obstacles to otherwise easy tasks like stretching.
# Generated: The caption humorously suggests that cats, like the black one standing on the yoga mat near the man's foot, can unexpectedly become adorable hindrances to simple activities such as stretching.
#
# ROUGE-1: Score(precision=0.12903225806451613, recall=0.4, fmeasure=0.1951219512195122)
# ROUGE-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-L: Score(precision=0.0967741935483871, recall=0.3, fmeasure=0.14634146341463414)
#
# Reference: why wouldn't anyone want to stay in san diego, it's beautiful.
# Generated: The caption humorously questions why anyone would want to stay in San Diego, despite the image showcasing its breathtaking city skyline at dusk, serene waterfront, and majestic mountains, which collectively exude a peaceful and inviting atmosphere.
#
# ROUGE-1: Score(precision=0.2222222222222222, recall=0.6153846153846154, fmeasure=0.326530612244898)
# ROUGE-2: Score(precision=0.14285714285714285, recall=0.4166666666666667, fmeasure=0.21276595744680848)
# ROUGE-L: Score(precision=0.2222222222222222, recall=0.6153846153846154, fmeasure=0.326530612244898)
#
# Reference: the author doesn't like such impolite note from her kid.
# Generated: The caption humorously describes a parent's reaction to finding a chocolate-stained note left by their child after a night out with friends, while the image adds to the humor with a hand-drawn "Mine" and a frowning face on a chocolate-stained paper, suggesting a playful and lighthearted situation.
#
# ROUGE-1: Score(precision=0.0392156862745098, recall=0.18181818181818182, fmeasure=0.06451612903225806)
# ROUGE-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-L: Score(precision=0.0392156862745098, recall=0.18181818181818182, fmeasure=0.06451612903225806)
#
# Reference: it seems gun control isn't working well after all in chicago, it only took two hours for the first murder of 2016.
# Generated: The meme, attributed to the "Conservative American Network," sarcastically highlights Chicago's high crime rate by claiming the city had its first murder of 2016 just two hours into the new year, and the caption criticizes gun control efforts, suggesting they are ineffective.
#
# ROUGE-1: Score(precision=0.23255813953488372, recall=0.43478260869565216, fmeasure=0.30303030303030304)
# ROUGE-2: Score(precision=0.11904761904761904, recall=0.22727272727272727, fmeasure=0.15624999999999997)
# ROUGE-L: Score(precision=0.13953488372093023, recall=0.2608695652173913, fmeasure=0.18181818181818182)
#
# Reference: someone's insensitive comment to get over it doesn't help.
# Generated: The caption and the comic strip together convey a satirical take on how people often dismiss others' feelings with insensitive comments, suggesting that if only we could instantly delete our feelings as easily as a computer file, we could respond to such insensitivity with humor and celebration, as depicted in the final panel where the character dances after being told to "get over it."
#
# ROUGE-1: Score(precision=0.09375, recall=0.5454545454545454, fmeasure=0.16)
# ROUGE-2: Score(precision=0.06349206349206349, recall=0.4, fmeasure=0.1095890410958904)
# ROUGE-L: Score(precision=0.09375, recall=0.5454545454545454, fmeasure=0.16)
#
# Reference: the author is disappointed with <user> for providing the uncomfortable wheelchair for her daughter.
# Generated: The caption expresses gratitude for a supportive wheelchair that aids the user's daughter, who is shown in the image sitting in a black wheelchair with pink accents, wearing a green jacket and a red bow, while holding her shoe in a public area near a Costa Coffee Express machine and a 1Life disability organization sign.
#
# ROUGE-1: Score(precision=0.16071428571428573, recall=0.6428571428571429, fmeasure=0.2571428571428572)
# ROUGE-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-L: Score(precision=0.08928571428571429, recall=0.35714285714285715, fmeasure=0.14285714285714285)
#
# Reference: the author is pissed to have so much snow gathered on the car.
# Generated: The caption humorously describes the effort of digging a snow-covered white sedan out of a snowy parking lot at night, with the hashtags and emojis likely adding a playful or frustrated tone to the situation.
#
# ROUGE-1: Score(precision=0.1111111111111111, recall=0.3076923076923077, fmeasure=0.163265306122449)
# ROUGE-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-L: Score(precision=0.08333333333333333, recall=0.23076923076923078, fmeasure=0.12244897959183675)
#
# Reference: the author got her <user> sample in the mail and it's a tiny sample.
# Generated: The caption expresses excitement about receiving a sample of Tic Tac Mixers Peach Lemonade, which is showcased in a close-up image of its vibrant, ombre-packaged design featuring peaches, lemons, and bubbles, with the brand and flavor names prominently displayed in both English and French.
#
# ROUGE-1: Score(precision=0.13043478260869565, recall=0.4, fmeasure=0.19672131147540983)
# ROUGE-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-L: Score(precision=0.10869565217391304, recall=0.3333333333333333, fmeasure=0.16393442622950818)
#
# Reference: the difficulty of being one person trying to house <num> personalities, caffine, tattoo's and baking, that's not cool.
# Generated: The image shows a person in a stylish red and white gingham apron standing in front of a white door, exuding a warm and inviting vibe, which contrasts with the caption's commentary on the complexity of managing multiple personalities.
#
# ROUGE-1: Score(precision=0.15, recall=0.3, fmeasure=0.2)
# ROUGE-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-L: Score(precision=0.1, recall=0.2, fmeasure=0.13333333333333333)
#
# Reference: the author seems to be tired of managing the food for the dogs.
# Generated: The caption humorously describes the owner's dedication to managing the feeding of two small dogs, where one has food allergies and the other might overeat, while the image shows the white dog eating from a bowl on a mat with the brown dog resting nearby.
#
# ROUGE-1: Score(precision=0.17391304347826086, recall=0.6153846153846154, fmeasure=0.2711864406779661)
# ROUGE-2: Score(precision=0.022222222222222223, recall=0.08333333333333333, fmeasure=0.03508771929824561)
# ROUGE-L: Score(precision=0.15217391304347827, recall=0.5384615384615384, fmeasure=0.23728813559322035)
#
# Reference: there're a lot of monitors in the studio.
# Generated: The caption humorously suggests a potential shortage of monitors in a well-equipped newsroom, which is actually filled with multiple television screens displaying live news, modern decor, and essential broadcast equipment, indicating a fully functional and technologically advanced broadcast studio.
#
# ROUGE-1: Score(precision=0.15, recall=0.6666666666666666, fmeasure=0.24489795918367346)
# ROUGE-2: Score(precision=0.05128205128205128, recall=0.25, fmeasure=0.0851063829787234)
# ROUGE-L: Score(precision=0.125, recall=0.5555555555555556, fmeasure=0.20408163265306123)
#
# Reference: the author hates paying for chunks of ice in the name of a smoothie.
# Generated: The image shows a person in a car holding a cup of a yellow beverage, likely a smoothie, with small ice cubes or fruit, while the caption humorously expresses frustration about the high cost of what is essentially "chunks of ice."
#
# ROUGE-1: Score(precision=0.21951219512195122, recall=0.6428571428571429, fmeasure=0.32727272727272727)
# ROUGE-2: Score(precision=0.1, recall=0.3076923076923077, fmeasure=0.15094339622641512)
# ROUGE-L: Score(precision=0.12195121951219512, recall=0.35714285714285715, fmeasure=0.18181818181818182)
#
# Reference: the author didn't find <user> a source of real news.
# Generated: The caption humorously suggests that the National Enquirer, known for sensational and often unreliable stories, is a source of "real news," while the image shows a magazine rack with the Enquirer featuring sensational headlines about Hillary Clinton, the Trump family, and celebrity gossip, alongside other products in a store.
#
# ROUGE-1: Score(precision=0.12244897959183673, recall=0.5454545454545454, fmeasure=0.2)
# ROUGE-2: Score(precision=0.08333333333333333, recall=0.4, fmeasure=0.13793103448275862)
# ROUGE-L: Score(precision=0.12244897959183673, recall=0.5454545454545454, fmeasure=0.2)
#
# Reference: there's something creepy about this panel.
# Generated: The caption humorously contrasts the seemingly friendly and unthreatening appearance of Uncle Joey, who invites children to listen to a story, with the #yikes hashtag, suggesting there might be something unsettling or inappropriate about the situation despite the panel's innocent appearance.
#
# ROUGE-1: Score(precision=0.11904761904761904, recall=0.7142857142857143, fmeasure=0.2040816326530612)
# ROUGE-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-L: Score(precision=0.09523809523809523, recall=0.5714285714285714, fmeasure=0.16326530612244897)
#
# Reference: it wasn't a top level service from <user>.
# Generated: The caption praises Sprint Care for their consistent high-quality service, while the image shows a Twitter conversation where a customer named Brad is interacting with both Sprint Care and Verizon Support, indicating a complex customer service situation.
#
# ROUGE-1: Score(precision=0.05263157894736842, recall=0.2222222222222222, fmeasure=0.0851063829787234)
# ROUGE-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-L: Score(precision=0.05263157894736842, recall=0.2222222222222222, fmeasure=0.0851063829787234)
#
# Reference: this isn't make-up, it's photoshoped.
# Generated: The caption humorously highlights the girl's improving makeup skills, noting her coordinated mascara and nails, while the image processing explanation describes a collage showing the same young blonde girl in black-and-white and color, both featuring her plaid shirt and chain-link bracelet.
#
# ROUGE-1: Score(precision=0.022222222222222223, recall=0.125, fmeasure=0.03773584905660377)
# ROUGE-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-L: Score(precision=0.022222222222222223, recall=0.125, fmeasure=0.03773584905660377)
#
# Reference: innocent people and not the swiss bank account holders and 2g scam accused have to rush towards the banks as modiji is hunting black money.
# Generated: The caption suggests that individuals with Swiss bank accounts and those accused in the 2G scam are urgently rushing to banks, possibly to withdraw or hide their funds, as Prime Minister Modi intensifies efforts to track down black money, while the image shows a large, anxious crowd waiting outside a bank, each holding documents.
#
# ROUGE-1: Score(precision=0.2777777777777778, recall=0.6, fmeasure=0.37974683544303794)
# ROUGE-2: Score(precision=0.07547169811320754, recall=0.16666666666666666, fmeasure=0.10389610389610389)
# ROUGE-L: Score(precision=0.2222222222222222, recall=0.48, fmeasure=0.3037974683544304)
#
# Reference: you've not made it in life when this is the view from your hotel room.
# Generated: The caption humorously suggests that a view of a well-maintained parking lot and commercial buildings from a hotel room is a sign of success, while the image description details a scene that contrasts the luxurious expectations typically associated with such a claim.
#
# ROUGE-1: Score(precision=0.13953488372093023, recall=0.375, fmeasure=0.20338983050847456)
# ROUGE-2: Score(precision=0.023809523809523808, recall=0.06666666666666667, fmeasure=0.03508771929824561)
# ROUGE-L: Score(precision=0.11627906976744186, recall=0.3125, fmeasure=0.16949152542372883)
#
# Reference: the author is disappointed with <user> for the very special delivery of not arriving on <num> separate booked dates.
# Generated: The caption expresses frustration with DX Delivery for failing to deliver a package on multiple scheduled dates, and the intent to escalate the issue to the company that used their service, while the image shows a poorly written email from DX Delivery explaining the delivery issue and providing contact information for a customer service agent.
#
# ROUGE-1: Score(precision=0.12727272727272726, recall=0.3684210526315789, fmeasure=0.18918918918918917)
# ROUGE-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-L: Score(precision=0.09090909090909091, recall=0.2631578947368421, fmeasure=0.13513513513513514)
#
# Reference: saying "don't be sad." doesn't cure people.
# Generated: The image humorously depicts a sarcastic "thank you" for curing someone's sadness, likely meant to be a playful jab at overly simplistic attempts to comfort someone, and is branded with the @REBEL_CIRCUS watermark.
#
# ROUGE-1: Score(precision=0.08571428571428572, recall=0.3333333333333333, fmeasure=0.13636363636363638)
# ROUGE-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-L: Score(precision=0.02857142857142857, recall=0.1111111111111111, fmeasure=0.04545454545454545)
#
# Reference: culvers bacon deluxe, it cannot get more unhealthy than this
# Generated: The caption humorously contrasts the indulgent, high-calorie nature of the Culver's Bacon Deluxe meal, which includes a double-patty cheeseburger with bacon, fries, and a drink, with the idea of "healthy living," while the image processing description confirms the meal's contents and packaging details.
#
# ROUGE-1: Score(precision=0.06382978723404255, recall=0.3, fmeasure=0.10526315789473684)
# ROUGE-2: Score(precision=0.021739130434782608, recall=0.1111111111111111, fmeasure=0.03636363636363637)
# ROUGE-L: Score(precision=0.06382978723404255, recall=0.3, fmeasure=0.10526315789473684)
#
# Reference: there's no disk required for netflix and the author is asked to insert a disk for it.
# Generated: The caption expresses the user's confusion about Netflix requiring a disc, likely due to the Xbox Live service being down, while the image shows an Xbox One screen failing to start Netflix and asking for a disc insertion or system restart, with Minecraft prominently displayed.
#
# ROUGE-1: Score(precision=0.21739130434782608, recall=0.5555555555555556, fmeasure=0.3125)
# ROUGE-2: Score(precision=0.022222222222222223, recall=0.058823529411764705, fmeasure=0.03225806451612903)
# ROUGE-L: Score(precision=0.13043478260869565, recall=0.3333333333333333, fmeasure=0.18750000000000003)
#
# Reference: chicken nuggets covered in hot sauce aren't healthy.
# Generated: The caption humorously contrasts the generally unhealthy perception of chicken nuggets with the idea of health, while the image shows a plate with a neat arrangement of crispy, pepper-seasoned nuggets drenched in a vibrant red hot sauce.
#
# ROUGE-1: Score(precision=0.13157894736842105, recall=0.5555555555555556, fmeasure=0.2127659574468085)
# ROUGE-2: Score(precision=0.05405405405405406, recall=0.25, fmeasure=0.08888888888888889)
# ROUGE-L: Score(precision=0.13157894736842105, recall=0.5555555555555556, fmeasure=0.2127659574468085)
#
# Reference: this is disgusting and misogynistic.
# Generated: The caption "how peaceful & loving" starkly contrasts with the controversial and violent content of the image, which includes a graphic quote from a religious text and a nude figure, creating a jarring and provocative statement.
#
# ROUGE-1: Score(precision=0.02857142857142857, recall=0.2, fmeasure=0.049999999999999996)
# ROUGE-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-L: Score(precision=0.02857142857142857, recall=0.2, fmeasure=0.049999999999999996)
#
# Reference: the author isn't shocked that a big dirty truck doesn't know how to park in yeg.
# Generated: The caption criticizes a large, dirty truck for poor parking in Edmonton (YEG), noting it extends beyond the marked space, while the image shows a white pickup truck with a dirty bumper partially obscuring the license plate, parked slightly over the yellow line in a lot.
#
# ROUGE-1: Score(precision=0.15217391304347827, recall=0.3888888888888889, fmeasure=0.21875000000000003)
# ROUGE-2: Score(precision=0.044444444444444446, recall=0.11764705882352941, fmeasure=0.06451612903225806)
# ROUGE-L: Score(precision=0.15217391304347827, recall=0.3888888888888889, fmeasure=0.21875000000000003)
#
# Reference: the author hates it when his mom forgets to get the only thing he asked her to get when she went shopping.
# Generated: The meme shows a man clapping in an office while captioning his frustration with his mom forgetting to buy the one thing he asked for, humorously highlighting a common relatable situation.
#
# ROUGE-1: Score(precision=0.2903225806451613, recall=0.4090909090909091, fmeasure=0.339622641509434)
# ROUGE-2: Score(precision=0.16666666666666666, recall=0.23809523809523808, fmeasure=0.19607843137254902)
# ROUGE-L: Score(precision=0.2903225806451613, recall=0.4090909090909091, fmeasure=0.339622641509434)
#
# Reference: the author is wearing the blue jersey to show his support to team india but there's a power cut.
# Generated: The caption expresses support for Team India in a cricket match against New Zealand in Bangalore, mentioning power cuts and the local electricity provider, while the image processing description indicates that the associated image is a blank black square, likely a placeholder.
#
# ROUGE-1: Score(precision=0.21428571428571427, recall=0.45, fmeasure=0.29032258064516125)
# ROUGE-2: Score(precision=0.04878048780487805, recall=0.10526315789473684, fmeasure=0.06666666666666667)
# ROUGE-L: Score(precision=0.16666666666666666, recall=0.35, fmeasure=0.22580645161290322)
#
# Reference: When preparing a presentation do not use giant fonts for everything, it does not make what you write correct
# Generated: The image humorously warns against the overuse of large fonts in presentations, suggesting that making the font huge can make any statement seem important, even if it's not, with a playful and visually striking design.
#
# ROUGE-1: Score(precision=0.16666666666666666, recall=0.3157894736842105, fmeasure=0.2181818181818182)
# ROUGE-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-L: Score(precision=0.1111111111111111, recall=0.21052631578947367, fmeasure=0.14545454545454545)
#
# Reference: less thinking doesn't mean more happiness.
# Generated: The image shows a man and a dog sitting on a bench, with the dog's thought bubbles filled with simple, relatable images, suggesting that the dog's happiness stems from its straightforward and contented thoughts, unlike humans who often overthink, as implied by the caption "This is why dogs are happier."
#
# ROUGE-1: Score(precision=0.019230769230769232, recall=0.14285714285714285, fmeasure=0.03389830508474577)
# ROUGE-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-L: Score(precision=0.019230769230769232, recall=0.14285714285714285, fmeasure=0.03389830508474577)
#
# Reference: windows updates aren't something that one wants when packing up to go home.
# Generated: The caption humorously expresses gratitude to Microsoft for ensuring the user has something to look forward to (a lengthy update process) when they are ready to leave, matching the image of a Windows update screen showing the installation of update two out of ninety-one, with a message advising against turning off the computer.
#
# ROUGE-1: Score(precision=0.1111111111111111, recall=0.42857142857142855, fmeasure=0.17647058823529413)
# ROUGE-2: Score(precision=0.018867924528301886, recall=0.07692307692307693, fmeasure=0.030303030303030304)
# ROUGE-L: Score(precision=0.05555555555555555, recall=0.21428571428571427, fmeasure=0.08823529411764706)
#
# Reference: the author isn't being enthusiastic in the train.
# Generated: The caption humorously contrasts the man's enthusiastic expression in the selfie with the mundane setting of being on a train, while the image processing description mistakenly identifies the setting as an airplane cabin, detailing his blue polo shirt, jacket, and pompadour hairstyle.
#
# ROUGE-1: Score(precision=0.13953488372093023, recall=0.6666666666666666, fmeasure=0.23076923076923078)
# ROUGE-2: Score(precision=0.023809523809523808, recall=0.125, fmeasure=0.04)
# ROUGE-L: Score(precision=0.11627906976744186, recall=0.5555555555555556, fmeasure=0.19230769230769232)
#
# Reference: the author's kids' lives aren't hell, they are happy.
# Generated: The caption sarcastically contrasts the apparent unhappiness of the kids in the image with the sympathetic and supportive tweet from Gregthurell, highlighting the discrepancy between the perceived and actual situations.
#
# ROUGE-1: Score(precision=0.06666666666666667, recall=0.18181818181818182, fmeasure=0.0975609756097561)
# ROUGE-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-L: Score(precision=0.06666666666666667, recall=0.18181818181818182, fmeasure=0.0975609756097561)
#
# Reference: completely free at the theatre this morning
# Generated: The caption "super busy at the theatre this morning" contrasts with the tranquil scene of a quiet movie theater captured from a car's parking perspective, featuring a prominent marquee and a serene landscape, suggesting a discrepancy between the expected and observed activity levels.
#
# ROUGE-1: Score(precision=0.11363636363636363, recall=0.7142857142857143, fmeasure=0.19607843137254902)
# ROUGE-2: Score(precision=0.09302325581395349, recall=0.6666666666666666, fmeasure=0.16326530612244897)
# ROUGE-L: Score(precision=0.11363636363636363, recall=0.7142857142857143, fmeasure=0.19607843137254902)
#
# Reference: it's no way to honor someone by taking to the streets, setting cars on fire, & looting a local mcdonalds.
# Generated: The image depicts a person standing in the middle of a smoke-filled road at night, with their arms raised, in front of a McDonald's, creating a dramatic and intense scene that contrasts with the familiar fast-food backdrop, seemingly in response to the caption's provocative and violent rhetoric.
#
# ROUGE-1: Score(precision=0.09803921568627451, recall=0.25, fmeasure=0.14084507042253522)
# ROUGE-2: Score(precision=0.02, recall=0.05263157894736842, fmeasure=0.028985507246376812)
# ROUGE-L: Score(precision=0.058823529411764705, recall=0.15, fmeasure=0.08450704225352114)
#
# Reference: out of the entire route 95, the worst roads are in nj, even though people pay their share of taxes.
# Generated: The caption criticizes New Jersey residents for poor road conditions on I-95, blaming inadequate tax contributions, while the image visually highlights the 51% of substandard road conditions in Essex County in 2015.
#
# ROUGE-1: Score(precision=0.21212121212121213, recall=0.35, fmeasure=0.26415094339622636)
# ROUGE-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-L: Score(precision=0.15151515151515152, recall=0.25, fmeasure=0.18867924528301888)
#
# Reference: red with white screen and silver lined botton is a bad color combination.
# Generated: The caption humorously refers to the iPhone 7's color scheme, suggesting it could have been entirely red or red with a black front, while the image shows a pinkish-red iPhone 7 with a white screen and silver buttons on a white background.
#
# ROUGE-1: Score(precision=0.18181818181818182, recall=0.6153846153846154, fmeasure=0.2807017543859649)
# ROUGE-2: Score(precision=0.09302325581395349, recall=0.3333333333333333, fmeasure=0.14545454545454545)
# ROUGE-L: Score(precision=0.1590909090909091, recall=0.5384615384615384, fmeasure=0.2456140350877193)
#
# Reference: the baby is crying in this picture.
# Generated: The caption expresses joy and nostalgia for a family portrait featuring a man, woman, and a crying baby, dressed formally in front of a house, with the baby's face blurred.
#
# ROUGE-1: Score(precision=0.12903225806451613, recall=0.5714285714285714, fmeasure=0.2105263157894737)
# ROUGE-2: Score(precision=0.03333333333333333, recall=0.16666666666666666, fmeasure=0.05555555555555555)
# ROUGE-L: Score(precision=0.0967741935483871, recall=0.42857142857142855, fmeasure=0.15789473684210525)
#
# Reference: it's ridiculous that hillary clinton is resisting all the good things like clean energy.
# Generated: The caption and image series satirically portray Hillary Clinton as the leader of the resistance, highlighting her stance on progressive issues like healthcare, workers' rights, and reform, while also reflecting the polarized political sentiments surrounding her, as indicated by hashtags like #stillneverhillary and #demexit.
#
# ROUGE-1: Score(precision=0.11363636363636363, recall=0.3333333333333333, fmeasure=0.16949152542372878)
# ROUGE-2: Score(precision=0.023255813953488372, recall=0.07142857142857142, fmeasure=0.03508771929824561)
# ROUGE-L: Score(precision=0.11363636363636363, recall=0.3333333333333333, fmeasure=0.16949152542372878)
#
# Reference: the author hates <user>'s growing a mustache because now her husband thinks he can have one too.
# Generated: The caption expresses gratitude to someone for growing a mustache, which inspired the man's husband to do the same, while the image shows a man with a neatly trimmed beard lying on a couch, capturing the essence of the #summerofstache trend.
#
# ROUGE-1: Score(precision=0.14285714285714285, recall=0.3333333333333333, fmeasure=0.2)
# ROUGE-2: Score(precision=0.04878048780487805, recall=0.11764705882352941, fmeasure=0.06896551724137931)
# ROUGE-L: Score(precision=0.11904761904761904, recall=0.2777777777777778, fmeasure=0.16666666666666663)
#
# Reference: she's exactly like her dad, both are making similar faces.
# Generated: The caption humorously suggests that the woman on the right, who is standing in front and wearing a light-colored sweater, doesn't resemble her father, despite the family's close bond, as shown in the selfie of the three individuals with a tech-lit background.
#
# ROUGE-1: Score(precision=0.043478260869565216, recall=0.18181818181818182, fmeasure=0.07017543859649122)
# ROUGE-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-L: Score(precision=0.021739130434782608, recall=0.09090909090909091, fmeasure=0.03508771929824561)
#
# Reference: It was pretty much expected that they'll announce the new call of duty at the e3 expo 2016
# Generated: The promotional poster for Call of Duty: Black Ops III, featuring a soldier amidst drones and smoke, vividly captures the intense and unexpected announcement of the game's presence at E3 Expo 2016, thrilling fans who were not anticipating this reveal.
#
# ROUGE-1: Score(precision=0.24390243902439024, recall=0.5263157894736842, fmeasure=0.3333333333333333)
# ROUGE-2: Score(precision=0.1, recall=0.2222222222222222, fmeasure=0.13793103448275865)
# ROUGE-L: Score(precision=0.1951219512195122, recall=0.42105263157894735, fmeasure=0.26666666666666666)
#
# Reference: it's inconvenient driving home through the mountains in the rain with a vomiting kid.
# Generated: The caption humorously contrasts the idyllic yet challenging journey of driving through scenic, foggy mountains in the rain with a sick child, while the image depicts a serene and misty road winding through a forest, capturing the essence of a peaceful but potentially stressful vacation drive.
#
# ROUGE-1: Score(precision=0.1956521739130435, recall=0.6, fmeasure=0.29508196721311475)
# ROUGE-2: Score(precision=0.1111111111111111, recall=0.35714285714285715, fmeasure=0.1694915254237288)
# ROUGE-L: Score(precision=0.17391304347826086, recall=0.5333333333333333, fmeasure=0.26229508196721313)
#
# Reference: a fall, cool weather favorite <user> doesn't taste like the middle of summer.
# Generated: The caption humorously contrasts the early arrival of fall flavors in the middle of summer, while the image shows a pumpkin spice coffee advertisement celebrating National Coffee Month with a customer favorite, suggesting that fall flavors are being marketed prematurely.
#
# ROUGE-1: Score(precision=0.175, recall=0.5, fmeasure=0.25925925925925924)
# ROUGE-2: Score(precision=0.07692307692307693, recall=0.23076923076923078, fmeasure=0.11538461538461538)
# ROUGE-L: Score(precision=0.125, recall=0.35714285714285715, fmeasure=0.18518518518518517)
#
# Reference: the author is pissed at <user> for such bad packaging.
# Generated: The caption sarcastically thanks a company for consistently poor service, while the image shows a carefully packed item in a box, suggesting a contrast between the sender's effort and the recipient's dissatisfaction.
#
# ROUGE-1: Score(precision=0.058823529411764705, recall=0.2, fmeasure=0.0909090909090909)
# ROUGE-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-L: Score(precision=0.058823529411764705, recall=0.2, fmeasure=0.0909090909090909)
#
# Reference: <user> didn't come out much better after cooking.
# Generated: The caption humorously suggests that the user improved after cooking, while the image shows a well-cooked, small, round pizza with pepperoni and cheese on a purple plate, indicating the quality of the cooking.
#
# ROUGE-1: Score(precision=0.08823529411764706, recall=0.3333333333333333, fmeasure=0.13953488372093023)
# ROUGE-2: Score(precision=0.030303030303030304, recall=0.125, fmeasure=0.04878048780487805)
# ROUGE-L: Score(precision=0.08823529411764706, recall=0.3333333333333333, fmeasure=0.13953488372093023)
#
# Reference: the author is not impressed by the rewards scheme since it's gonna take her twice as long now for free rewards.
# Generated: The caption and the image together suggest a scenario where the person is expressing frustration with changes to the Starbucks Rewards program. Here's a breakdown:
#
# ### Caption:
# "So much for free rewards, gonna take me twice as long now. thanks <user>"
#
# - **"So much for free rewards"**: This indicates disappointment or frustration with the changes to the rewards program. The person expected to receive free rewards more easily, but the changes have made it more difficult.
# - **"gonna take me twice as long now"**: This suggests that the new requirements for earning rewards are significantly more demanding, making it take twice as long to earn the same rewards as before.
# - **"thanks <user>"**: This is likely sarcastic, implying that the changes are not appreciated and that the person is not thankful for them.
#
# ### Image:
# The image shows a person holding a Starbucks Rewards pamphlet, with a blue toy car and other objects on the floor in the background. The pamphlet details the new reward program, which includes:
#
# - **Starting April 1, for every $1 spent, members will earn 2 stars, which can be redeemed for rewards.**
# - **Members can earn:**
#   - **1 star per visit**
#   - **30 stars to reach Gold level**
#   - **12 stars for a free reward in Gold level**
#   - **2 stars per $1 spent**
#   - **300 stars to reach Gold level**
#   - **125 stars for a free reward in Gold level**
#   - **Green and Gold levels, with new Gold benefits, in just one sentence**
#
# ### Explanation:
# The person is likely frustrated because the new reward system requires more stars to achieve the same benefits. For example, reaching the Gold level now requires 300 stars instead of 30, and earning a free reward in the Gold level now requires 125 stars instead of 12. This makes it much harder and time-consuming to earn rewards, hence the sarcastic "thanks" in the caption.
#
# The blue toy car and other objects in the background might be a personal touch, possibly indicating that the person is at home or in a casual setting while reviewing the new reward program.
#
# ROUGE-1: Score(precision=0.047619047619047616, recall=0.7272727272727273, fmeasure=0.08938547486033518)
# ROUGE-2: Score(precision=0.023880597014925373, recall=0.38095238095238093, fmeasure=0.0449438202247191)
# ROUGE-L: Score(precision=0.041666666666666664, recall=0.6363636363636364, fmeasure=0.0782122905027933)
#
# Reference: such useless response doesn't make asos the most helpful of people.
# Generated: The caption sarcastically comments on ASOS's customer service, which informs the user that the return process has become more complicated and will take longer, despite the implication that ASOS should be helpful.
#
# ROUGE-1: Score(precision=0.09090909090909091, recall=0.25, fmeasure=0.13333333333333333)
# ROUGE-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-L: Score(precision=0.09090909090909091, recall=0.25, fmeasure=0.13333333333333333)
#
# Reference: with such chillin pre-game in the rink lounge it's obvious how n has survived this for <num> years.
# Generated: The caption describes a group relaxing in a well-appointed sports lounge with a TV, fireplace, and comfortable seating, while the image processing explanation details the room's features, including a black wall with a TV showing a soccer game, a fireplace, black leather furniture, high-top tables, a window view of a stadium, and a red wall with a silver shutter.
#
# ROUGE-1: Score(precision=0.0967741935483871, recall=0.3, fmeasure=0.14634146341463414)
# ROUGE-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-L: Score(precision=0.04838709677419355, recall=0.15, fmeasure=0.07317073170731707)
#
# Reference: the author is pissed at <user> for such outdated website about power outages.
# Generated: The user is impressed by the modern and informative design of the Tata Power website, which clearly communicates potential power outages, despite the inconvenience, and humorously suggests it's a fitting gift for Buddha Purnima.
#
# ROUGE-1: Score(precision=0.2, recall=0.5384615384615384, fmeasure=0.2916666666666667)
# ROUGE-2: Score(precision=0.029411764705882353, recall=0.08333333333333333, fmeasure=0.04347826086956522)
# ROUGE-L: Score(precision=0.14285714285714285, recall=0.38461538461538464, fmeasure=0.20833333333333331)
#
# Reference: the author doesn't look excited that it's time for a run.
# Generated: The caption expresses the man's excitement about going for a run, which is reflected in the image showing him dressed and ready, holding his phone to take a selfie with his dog.
#
# ROUGE-1: Score(precision=0.18181818181818182, recall=0.46153846153846156, fmeasure=0.26086956521739135)
# ROUGE-2: Score(precision=0.0625, recall=0.16666666666666666, fmeasure=0.09090909090909091)
# ROUGE-L: Score(precision=0.15151515151515152, recall=0.38461538461538464, fmeasure=0.21739130434782608)
#
# Reference: some women just don’t know how to have natural eyebrows
# Generated: The meme depicts a scornful blonde woman, humorously captioned to comment on the irony of someone claiming their eyebrows look natural, suggesting they are obviously styled or enhanced.
#
# ROUGE-1: Score(precision=0.10714285714285714, recall=0.2727272727272727, fmeasure=0.15384615384615383)
# ROUGE-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-L: Score(precision=0.07142857142857142, recall=0.18181818181818182, fmeasure=0.10256410256410255)
#
# Reference: it isn't a loss to not have to deal with someone who is rude to you.
# Generated: The meme humorously depicts Gene Wilder as Willy Wonka sarcastically responding to someone who claims they'll never return, by playfully suggesting that dealing with their rude behavior is not something to be missed.
#
# ROUGE-1: Score(precision=0.2647058823529412, recall=0.5294117647058824, fmeasure=0.35294117647058826)
# ROUGE-2: Score(precision=0.06060606060606061, recall=0.125, fmeasure=0.0816326530612245)
# ROUGE-L: Score(precision=0.14705882352941177, recall=0.29411764705882354, fmeasure=0.19607843137254904)
#
# Reference: this is a spam tweet.
# Generated: The caption 'good news! found a new job!' contrasts sharply with the image of a promoted tweet offering potentially lucrative daily earnings, suggesting a discrepancy between the stated good news and the actual content of the job offer.
#
# ROUGE-1: Score(precision=0.05263157894736842, recall=0.4, fmeasure=0.09302325581395349)
# ROUGE-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-L: Score(precision=0.05263157894736842, recall=0.4, fmeasure=0.09302325581395349)
#
# Reference: this is a phishing email, no indicator can help you buy stocks that go up 100% of the time.
# Generated: The image depicts a promotional page for a stock market indicator that claims to help users identify and buy only stocks that are guaranteed to increase in price, supported by visually appealing charts and a compelling narrative, suggesting the potential for significant financial gains.
#
# ROUGE-1: Score(precision=0.1590909090909091, recall=0.3684210526315789, fmeasure=0.22222222222222218)
# ROUGE-2: Score(precision=0.023255813953488372, recall=0.05555555555555555, fmeasure=0.032786885245901634)
# ROUGE-L: Score(precision=0.1590909090909091, recall=0.3684210526315789, fmeasure=0.22222222222222218)
#
# Reference: there are a lot of montreal media members at claude julien news conference in new york hotel.
# Generated: The caption and image description together suggest that the photo captures Claude Julien, likely the coach of the Montreal Canadiens (nicknamed #habs), at a press conference in a New York hotel during the 2017 Stanley Cup Playoffs, with a few Montreal media members in attendance, emphasizing the event's significance and the anticipation surrounding the playoffs.
#
# ROUGE-1: Score(precision=0.23214285714285715, recall=0.7647058823529411, fmeasure=0.35616438356164387)
# ROUGE-2: Score(precision=0.10909090909090909, recall=0.375, fmeasure=0.16901408450704225)
# ROUGE-L: Score(precision=0.14285714285714285, recall=0.47058823529411764, fmeasure=0.2191780821917808)
#
# Reference: the size of the author's largemouth bass is very small.
# Generated: The image shows a person in a boat proudly holding a small fish, humorously claiming to be the greatest fisherman ever, while the serene surroundings and their unique attire add to the whimsical scene.
#
# ROUGE-1: Score(precision=0.08823529411764706, recall=0.2727272727272727, fmeasure=0.13333333333333333)
# ROUGE-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-L: Score(precision=0.058823529411764705, recall=0.18181818181818182, fmeasure=0.08888888888888888)
#
# Reference: snow showers aren't what the author wanted today.
# Generated: The caption expresses satisfaction with the weather app showing a 10% chance of snow in Richmond, with a temperature of 0 degrees and a wind chill between 1 and 4 degrees, set against a grey background.
#
# ROUGE-1: Score(precision=0.05555555555555555, recall=0.2222222222222222, fmeasure=0.08888888888888888)
# ROUGE-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-L: Score(precision=0.027777777777777776, recall=0.1111111111111111, fmeasure=0.04444444444444444)
#
# Reference: that's a crude speech.
# Generated: The meme humorously presents Zimbabwe President Robert Mugabe's anti-racism speech in a playful font, captioned as a "perfect speech."
#
# ROUGE-1: Score(precision=0.14285714285714285, recall=0.6, fmeasure=0.23076923076923073)
# ROUGE-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-L: Score(precision=0.14285714285714285, recall=0.6, fmeasure=0.23076923076923073)
#
# Reference: the author doesn't like to use windows, it's inconvenient.
# Generated: The caption 'Windows is such a joy to use' is likely sarcastic, given the image showing a slow and potentially tedious Windows installation process with a progress bar at only 10%.
#
# ROUGE-1: Score(precision=0.16129032258064516, recall=0.45454545454545453, fmeasure=0.23809523809523805)
# ROUGE-2: Score(precision=0.03333333333333333, recall=0.1, fmeasure=0.05)
# ROUGE-L: Score(precision=0.12903225806451613, recall=0.36363636363636365, fmeasure=0.19047619047619047)
#
# Reference: over priced hotel food, subway or dunking donuts, the author doesn't have many choices in brooklyn tonight.
# Generated: The caption humorously contrasts overpriced hotel food with more affordable options like Subway or Dunkin' Donuts, reflecting the diverse and budget-friendly dining choices in Brooklyn, while the image processing description confirms the setting as a typical Subway restaurant with a variety of menu options.
#
# ROUGE-1: Score(precision=0.2, recall=0.5, fmeasure=0.28571428571428575)
# ROUGE-2: Score(precision=0.09090909090909091, recall=0.23529411764705882, fmeasure=0.13114754098360656)
# ROUGE-L: Score(precision=0.2, recall=0.5, fmeasure=0.28571428571428575)
#
# Reference: it can't be just $10 for a kawasaki motorcycle.
# Generated: The caption expresses amazement at a Facebook ad for a black Kawasaki motorcycle priced at $10 on the Wish app, which is featured with a 5-star rating and a call to action to shop now.
#
# ROUGE-1: Score(precision=0.1388888888888889, recall=0.5, fmeasure=0.2173913043478261)
# ROUGE-2: Score(precision=0.05714285714285714, recall=0.2222222222222222, fmeasure=0.0909090909090909)
# ROUGE-L: Score(precision=0.1111111111111111, recall=0.4, fmeasure=0.1739130434782609)
#
# Reference: the author is sad to live in a state that doesn't have their priorities right.
# Generated: The caption "happy to live in a state that has their priorities right. :) #chicago" suggests that the person is pleased with the policies or values of the state they live in, specifically Chicago. The use of a smiley face and the hashtag #chicago indicates a positive sentiment and a connection to the city.
#
# The image processing explanation reveals a receipt that includes a purchase of a "200z sugar tax bottle" for $0.20, with a total purchase amount of $32.09, including a tax of $0.19. The receipt also lists other items, such as Sprite Zero NR for $1.89 and Pump #3 for $30.00.
#
# The context of the caption and the receipt can be interpreted as follows: The person is likely happy about the state's implementation of a sugar tax, which is often seen as a measure to promote healthier choices and reduce sugar consumption. The small price of the sugar tax bottle ($0.20) and the minimal tax ($0.19) on the total purchase suggest that the state is applying the tax in a way that is not overly burdensome but still sends a message about health priorities. This aligns with the person's positive sentiment about living in a state that values health and well-being.
#
# ROUGE-1: Score(precision=0.05188679245283019, recall=0.6875, fmeasure=0.09649122807017543)
# ROUGE-2: Score(precision=0.03317535545023697, recall=0.4666666666666667, fmeasure=0.06194690265486726)
# ROUGE-L: Score(precision=0.04716981132075472, recall=0.625, fmeasure=0.08771929824561404)
#
# Reference: starbucks using these non-white cups for spring doesn't mean they hate white and are un-american.
# Generated: The caption expresses a misguided and racially charged interpretation of Starbucks' spring cup design, which features a teal cup with the phrase "Clean Me Spring!" written in black, while the image processing description clarifies that the cup has a white lid and is placed on a car dashboard.
#
# ROUGE-1: Score(precision=0.10416666666666667, recall=0.2777777777777778, fmeasure=0.15151515151515152)
# ROUGE-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-L: Score(precision=0.10416666666666667, recall=0.2777777777777778, fmeasure=0.15151515151515152)
#
# Reference: it's not inspiring that trump doesn't know what is uranium precisely.
# ...
#
# ROUGE-1: Score(precision=0.14705882352941177, recall=0.35714285714285715, fmeasure=0.20833333333333334)
# ROUGE-2: Score(precision=0.030303030303030304, recall=0.07692307692307693, fmeasure=0.043478260869565216)
# ROUGE-L: Score(precision=0.11764705882352941, recall=0.2857142857142857, fmeasure=0.16666666666666666)
#
# Reference: every winter, the author is reminded of how inconvenient it is to have a corner lot.
# Generated: The caption expresses joy about the benefits of a corner lot in winter, while the image shows a person bundled up in a snow-covered hooded jacket, standing outside on a cold day, with a blue sky and leafless trees in the background.
#
# ROUGE-1: Score(precision=0.13953488372093023, recall=0.375, fmeasure=0.20338983050847456)
# ROUGE-2: Score(precision=0.047619047619047616, recall=0.13333333333333333, fmeasure=0.07017543859649122)
# ROUGE-L: Score(precision=0.11627906976744186, recall=0.3125, fmeasure=0.16949152542372883)
#
# Reference: the author doesn't need a rodeohusband just so her fashion sense counts.
# Generated: The caption humorously expresses a desire for a 'rodeohusband' to validate the user's fashion sense before others notice they're single, while the image shows a notification that the Instagram account "rodeowives" has started following the user, featuring a profile picture of a couple in western attire.
#
# ROUGE-1: Score(precision=0.10416666666666667, recall=0.38461538461538464, fmeasure=0.16393442622950818)
# ROUGE-2: Score(precision=0.0425531914893617, recall=0.16666666666666666, fmeasure=0.06779661016949153)
# ROUGE-L: Score(precision=0.10416666666666667, recall=0.38461538461538464, fmeasure=0.16393442622950818)
#
# Reference: the author doesn't seem busy looking at the type of apps.
# Generated: The caption "look at how busy I am" humorously suggests that the multitude of apps and a notification on the iPhone screen indicate a busy and active digital life.
#
# ROUGE-1: Score(precision=0.2413793103448276, recall=0.5833333333333334, fmeasure=0.34146341463414637)
# ROUGE-2: Score(precision=0.07142857142857142, recall=0.18181818181818182, fmeasure=0.10256410256410255)
# ROUGE-L: Score(precision=0.20689655172413793, recall=0.5, fmeasure=0.2926829268292683)
#
# Reference: 4 micro-USB cables in the car & not 1 iPhone cable doesn't make sense considering the author doesn't have any micro-USB devices & does have an iPhone.
# Generated: The caption humorously points out the irony of having multiple micro-USB cables in the car but no iPhone cable, despite not owning any micro-USB devices and owning an iPhone, while the image processing description highlights the variety of connectors, suggesting the person is tech-savvy but also a bit disorganized.
#
# ROUGE-1: Score(precision=0.3269230769230769, recall=0.5862068965517241, fmeasure=0.41975308641975306)
# ROUGE-2: Score(precision=0.19607843137254902, recall=0.35714285714285715, fmeasure=0.2531645569620253)
# ROUGE-L: Score(precision=0.2692307692307692, recall=0.4827586206896552, fmeasure=0.345679012345679)
#
# Reference: need human rights.
# Generated: The caption "no more human rights! #ge2017 #childrenofmen" and the image depict a dystopian scene of heavy police presence and crowd control, where a diverse group of people is confined and appears fearful, evoking themes of loss of freedom and human rights, similar to the film "Children of Men."
#
# ROUGE-1: Score(precision=0.04081632653061224, recall=0.6666666666666666, fmeasure=0.07692307692307691)
# ROUGE-2: Score(precision=0.020833333333333332, recall=0.5, fmeasure=0.039999999999999994)
# ROUGE-L: Score(precision=0.04081632653061224, recall=0.6666666666666666, fmeasure=0.07692307692307691)
#
# Reference: these aren't positive feedback.
# Generated: The caption sarcastically highlights the overwhelming positive feedback, contrasting with the hashtag suggestions of poor marketing and the need to fire the agency, while the image shows a clean, simple Fox Carolina webpage with a menu bar, search bar, and a list of varied comments.
#
# ROUGE-1: Score(precision=0.044444444444444446, recall=0.4, fmeasure=0.07999999999999999)
# ROUGE-2: Score(precision=0.022727272727272728, recall=0.25, fmeasure=0.04166666666666667)
# ROUGE-L: Score(precision=0.044444444444444446, recall=0.4, fmeasure=0.07999999999999999)
#
# Reference: the author hates winter, her windshield is covered with ice.
# Generated: The caption expresses sarcastic gratitude and frustration towards a harsh Iowa winter, while the image shows a car's icy windshield with a small clear patch, captured at night.
#
# ROUGE-1: Score(precision=0.13793103448275862, recall=0.4, fmeasure=0.20512820512820515)
# ROUGE-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-L: Score(precision=0.13793103448275862, recall=0.4, fmeasure=0.20512820512820515)
#
# Reference: this board isn't clever.
# Generated: The image shows a sign from the GILLIO LAW FIRM in Slidell celebrating Veterans Day with a message that ties the importance of veterans to the NFL and free speech, while using a provocative tone to criticize those perceived as complainers, and is tagged with hashtags reflecting political and social sentiments.
#
# ROUGE-1: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-L: Score(precision=0.0, recall=0.0, fmeasure=0.0)
#
# Reference: this makes the author's mind clearer for not voting for trump.
# Generated: The caption expresses dissatisfaction with Hillary Clinton and Bernie Sanders, showing support for Donald Trump, while the image depicts a chaotic and tense scene at a postponed Trump rally, suggesting the rally was disrupted by an incident that caused panic and distress.
#
# ROUGE-1: Score(precision=0.07142857142857142, recall=0.25, fmeasure=0.11111111111111112)
# ROUGE-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-L: Score(precision=0.07142857142857142, recall=0.25, fmeasure=0.11111111111111112)
#
# Reference: the author isn't enjoying this event due to such authentication errors.
# Generated: The caption expresses excitement about an event, while the image processing explanation describes a screen from the Pokémon Trainer Club app showing an authentication error with an "OK" button.
#
# ROUGE-1: Score(precision=0.13333333333333333, recall=0.3333333333333333, fmeasure=0.19047619047619044)
# ROUGE-2: Score(precision=0.034482758620689655, recall=0.09090909090909091, fmeasure=0.05)
# ROUGE-L: Score(precision=0.13333333333333333, recall=0.3333333333333333, fmeasure=0.19047619047619044)
#
# Reference: leak hasn't been fixed.
# Generated: The caption "leak fixed!" is ironic, as the image actually depicts a chaotic garage floor with a puddle of blood and a wrench, suggesting a violent or traumatic event rather than a simple leak repair.
#
# ROUGE-1: Score(precision=0.05714285714285714, recall=0.4, fmeasure=0.09999999999999999)
# ROUGE-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-L: Score(precision=0.05714285714285714, recall=0.4, fmeasure=0.09999999999999999)
#
# Reference: this guy isn't racist, given he wants to include children of every color in the american dream.
# Generated: The caption criticizes Donald Trump as racist, using emojis for emphasis, despite the image showing him quoting a statement about addressing African-American poverty and inclusion in the American Dream.
#
# ROUGE-1: Score(precision=0.16666666666666666, recall=0.2777777777777778, fmeasure=0.20833333333333334)
# ROUGE-2: Score(precision=0.10344827586206896, recall=0.17647058823529413, fmeasure=0.13043478260869565)
# ROUGE-L: Score(precision=0.16666666666666666, recall=0.2777777777777778, fmeasure=0.20833333333333334)
#
# Reference: bossiness isn't same as leadership and it shouldn't be the way forward.
# Generated: The caption humorously contrasts the playful, bossy interaction between two children in old-fashioned attire with a modern, empowering message about women in business, using lighthearted emojis and a supportive hashtag.
#
# ROUGE-1: Score(precision=0.0967741935483871, recall=0.21428571428571427, fmeasure=0.13333333333333333)
# ROUGE-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-L: Score(precision=0.06451612903225806, recall=0.14285714285714285, fmeasure=0.08888888888888889)
#
# Reference: <user> is inconvenient for tall people due to so little leg room.
# Generated: The caption humorously suggests that the person is "super awesome for tall people" because the image shows a tall individual struggling with limited legroom in an airplane seat, a common issue for taller passengers, while the hashtag "#howisthislegal" questions the fairness of such cramped conditions.
#
# ROUGE-1: Score(precision=0.08888888888888889, recall=0.3333333333333333, fmeasure=0.14035087719298245)
# ROUGE-2: Score(precision=0.045454545454545456, recall=0.18181818181818182, fmeasure=0.07272727272727272)
# ROUGE-L: Score(precision=0.08888888888888889, recall=0.3333333333333333, fmeasure=0.14035087719298245)
#
# Reference: <user>'s dagwood sandwich is too big to be eaten conveniently.
# Generated: The caption humorously suggests that the large sandwich, which is already bigger than the hand shown with a wedding band and fingers raised, should be even more enormous, emphasizing the idea with the hashtag "yuge."
#
# ROUGE-1: Score(precision=0.08571428571428572, recall=0.2727272727272727, fmeasure=0.13043478260869562)
# ROUGE-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-L: Score(precision=0.08571428571428572, recall=0.2727272727272727, fmeasure=0.13043478260869562)
#
# Reference: the author is sad that if her kids get sick some druggo in bendigo is getting looked after better than them.
# Generated: The caption expresses frustration and irony, suggesting that the author feels their children would receive inferior medical care compared to drug users in Bendigo, where an article in the depicted newspaper discusses the rise in methamphetamine use and related health issues, including the spread of Hepatitis and AIDS through syringe use.
#
# ROUGE-1: Score(precision=0.09803921568627451, recall=0.23809523809523808, fmeasure=0.1388888888888889)
# ROUGE-2: Score(precision=0.04, recall=0.1, fmeasure=0.05714285714285714)
# ROUGE-L: Score(precision=0.0784313725490196, recall=0.19047619047619047, fmeasure=0.1111111111111111)
#
# Reference: the author isn't good at drawing, look at this drawing.
# Generated: The caption "i can draw so good ..." humorously contrasts with the image, which shows a vibrant, well-detailed cartoon landscape of a sunset over blue water with palm trees, suggesting the artist's modesty or playful self-deprecation.
#
# ROUGE-1: Score(precision=0.07894736842105263, recall=0.2727272727272727, fmeasure=0.12244897959183672)
# ROUGE-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-L: Score(precision=0.05263157894736842, recall=0.18181818181818182, fmeasure=0.08163265306122448)
#
# Reference: the author doesn't seem to love being out with their family.
# Generated: The caption expresses enthusiasm for family outings with a playful hint about pizza, while the image shows two fashionably dressed young people enjoying a meal in a lively, crowded restaurant.
#
# ROUGE-1: Score(precision=0.1, recall=0.25, fmeasure=0.14285714285714288)
# ROUGE-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-L: Score(precision=0.06666666666666667, recall=0.16666666666666666, fmeasure=0.09523809523809522)
#
# Reference: it didn't go well, sniper was horrible.
# Generated: The caption humorously describes a successful but chaotic live streaming session, possibly featuring a sniper game, while the image shows a dark room setup with a microphone and a computer screen displaying a cartoon character and promotional text, suggesting it's a live stream or recording environment.
#
# ROUGE-1: Score(precision=0.0425531914893617, recall=0.25, fmeasure=0.07272727272727272)
# ROUGE-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-L: Score(precision=0.02127659574468085, recall=0.125, fmeasure=0.03636363636363636)
#
# Reference: that's not the author's last name, it's a misprint.
# Generated: The caption humorously announces a name change, sarcastically suggesting it's a significant and sudden change, while the image shows an official envelope with a name scribbled out, likely mocking the idea of such a formal announcement for a trivial matter.
#
# ROUGE-1: Score(precision=0.12195121951219512, recall=0.4166666666666667, fmeasure=0.18867924528301888)
# ROUGE-2: Score(precision=0.05, recall=0.18181818181818182, fmeasure=0.07843137254901962)
# ROUGE-L: Score(precision=0.12195121951219512, recall=0.4166666666666667, fmeasure=0.18867924528301888)
#
# Reference: the author is disappointed with this eclipse since it's not what she thought it would be.
# Generated: The caption expresses excitement about the solar eclipse, despite a hint of disappointment, while the image description details a sky with a striking cloud formation that seems to be illuminated and moving away from the foreground.
#
# ROUGE-1: Score(precision=0.1388888888888889, recall=0.29411764705882354, fmeasure=0.18867924528301885)
# ROUGE-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-L: Score(precision=0.1111111111111111, recall=0.23529411764705882, fmeasure=0.1509433962264151)
#
# Reference: this guy has parked his car partially covering the parking slot for handicapped.
# Generated: The caption sarcastically awards a "gold star" for poor parking, as the image shows a white car improperly occupying a handicap space at a Walmart, with no visible placard, and the car is parked in a way that blocks wheelchair access.
#
# ROUGE-1: Score(precision=0.14634146341463414, recall=0.46153846153846156, fmeasure=0.2222222222222222)
# ROUGE-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-L: Score(precision=0.0975609756097561, recall=0.3076923076923077, fmeasure=0.14814814814814817)
#
# Reference: the author is pissed at their elected mla and mp for raising hell regards to their nw region losing a service for the people.
# Generated: The caption expresses gratitude to the local Member of the Legislative Assembly (MLA) and Member of Parliament (MP) for their efforts in protesting the closure of a service in the northwest region, which affects the local community. The image notice confirms the permanent closure of the Can/Sask Labour Market Services office in Ile a la Crosse, effective June 14, 2017, at 5 pm.
#
# ROUGE-1: Score(precision=0.1875, recall=0.5, fmeasure=0.2727272727272727)
# ROUGE-2: Score(precision=0.047619047619047616, recall=0.13043478260869565, fmeasure=0.06976744186046512)
# ROUGE-L: Score(precision=0.140625, recall=0.375, fmeasure=0.20454545454545456)
#
# Reference: one hates when apple cords don't last longer than even 5 months.
# Generated: The caption sarcastically thanks Apple for a Lightning cable that has only lasted five months, shown in an image of a broken cord with a damaged white part and a silver connector, placed in front of a car's steering wheel.
#
# ROUGE-1: Score(precision=0.0975609756097561, recall=0.3076923076923077, fmeasure=0.14814814814814817)
# ROUGE-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-L: Score(precision=0.07317073170731707, recall=0.23076923076923078, fmeasure=0.1111111111111111)
#
# Reference: it's possible that trump's 'original renoir' painting is fake.
# Generated: The caption "no way!!" expresses surprise or disbelief at the news that a painting claimed by Trump to be an original Renoir and owned by him is actually a fake, as declared by the Chicago museum, with the post garnering 677 likes and featuring a blurry image of the artwork.
#
# ROUGE-1: Score(precision=0.14, recall=0.6363636363636364, fmeasure=0.22950819672131148)
# ROUGE-2: Score(precision=0.02040816326530612, recall=0.1, fmeasure=0.033898305084745756)
# ROUGE-L: Score(precision=0.12, recall=0.5454545454545454, fmeasure=0.19672131147540983)
#
# Average ROUGE-1 F1: 0.1915638014331679
# Average ROUGE-2 F1: 0.05049486418040401
# Average ROUGE-L F1: 0.1534415770550331

# %%
from collections import Counter

def simple_meteor_score(reference, e_new):
    def word_matches(ref, hyp):
        ref_counter = Counter(ref.split())
        hyp_counter = Counter(hyp.split())
        
        matches = sum(min(ref_counter[word], hyp_counter[word]) for word in hyp_counter)
        
        return matches
    
    def precision_recall(matches, reference_len, e_new_len):
        precision = matches / e_new_len if e_new_len > 0 else 0
        
        recall = matches / reference_len if reference_len > 0 else 0
        
        return precision, recall
    
    all_scores = []
    
    for hyp in e_new:
        hypothesis_scores = []
        for ref in reference:
            matches = word_matches(ref, hyp)
            precision, recall = precision_recall(matches, len(ref.split()), len(hyp.split()))

            if precision + recall == 0:
                f_mean = 0
            else:
                f_mean = (10 * precision * recall) / (9 * precision + recall)
            
            hypothesis_scores.append(f_mean)
        all_scores.append(max(hypothesis_scores))
    return np.mean(all_scores)


meteor_score = simple_meteor_score(references, e_new)
print(f"Simplified METEOR score: {meteor_score:.4f}")
# Out:
# Simplified METEOR score: 0.3519
